# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Help-With-jupyter-(ipython)-Notebooks" data-toc-modified-id="Help-With-jupyter-(ipython)-Notebooks-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Help With <code>jupyter</code> (<code>ipython</code>) Notebooks</a></span></li><li><span><a href="#A-Quick-Run-Through-Of-Pandas" data-toc-modified-id="A-Quick-Run-Through-Of-Pandas-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>A Quick Run-Through Of Pandas</a></span><ul class="toc-item"><li><span><a href="#The-Preamble" data-toc-modified-id="The-Preamble-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>The Preamble</a></span></li><li><span><a href="#Loading-and-Having-a-Quick-Peak-Into-a-Dataset" data-toc-modified-id="Loading-and-Having-a-Quick-Peak-Into-a-Dataset-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Loading and Having a Quick Peak Into a Dataset</a></span></li><li><span><a href="#Schema,-Structure,-Datatypes,-Distribution" data-toc-modified-id="Schema,-Structure,-Datatypes,-Distribution-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Schema, Structure, Datatypes, Distribution</a></span></li><li><span><a href="#numpy-Is-Behind-The-Scenes" data-toc-modified-id="numpy-Is-Behind-The-Scenes-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span><code>numpy</code> Is Behind The Scenes</a></span></li><li><span><a href="#Index,-Row-and-Column-Labels" data-toc-modified-id="Index,-Row-and-Column-Labels-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Index, Row and Column Labels</a></span></li><li><span><a href="#Just-A-Quick-Look-At-The-Data?" data-toc-modified-id="Just-A-Quick-Look-At-The-Data?-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Just A Quick Look At The Data?</a></span></li><li><span><a href="#A-Smaller,-Simpler-Example:-DataFrames-From-Dictionaries" data-toc-modified-id="A-Smaller,-Simpler-Example:-DataFrames-From-Dictionaries-2.7"><span class="toc-item-num">2.7&nbsp;&nbsp;</span>A Smaller, Simpler Example: <code>DataFrame</code>s From Dictionaries</a></span><ul class="toc-item"><li><span><a href="#Starting-With-A-Series-Object" data-toc-modified-id="Starting-With-A-Series-Object-2.7.1"><span class="toc-item-num">2.7.1&nbsp;&nbsp;</span>Starting With A <code>Series</code> Object</a></span></li><li><span><a href="#A-Quick-Look-At-Series" data-toc-modified-id="A-Quick-Look-At-Series-2.7.2"><span class="toc-item-num">2.7.2&nbsp;&nbsp;</span>A Quick Look At <code>Series</code></a></span></li><li><span><a href="#Another-Series" data-toc-modified-id="Another-Series-2.7.3"><span class="toc-item-num">2.7.3&nbsp;&nbsp;</span>Another <code>Series</code></a></span></li><li><span><a href="#A-DataFrame-From-A-Set-Of-Series-Objects" data-toc-modified-id="A-DataFrame-From-A-Set-Of-Series-Objects-2.7.4"><span class="toc-item-num">2.7.4&nbsp;&nbsp;</span>A <code>DataFrame</code> From A Set Of <code>Series</code> Objects</a></span></li></ul></li><li><span><a href="#Indexing-DataFrames" data-toc-modified-id="Indexing-DataFrames-2.8"><span class="toc-item-num">2.8&nbsp;&nbsp;</span>Indexing <code>DataFrame</code>s</a></span></li><li><span><a href="#Size-and-Shape" data-toc-modified-id="Size-and-Shape-2.9"><span class="toc-item-num">2.9&nbsp;&nbsp;</span>Size and Shape</a></span></li><li><span><a href="#Boolean-Masks" data-toc-modified-id="Boolean-Masks-2.10"><span class="toc-item-num">2.10&nbsp;&nbsp;</span>Boolean Masks</a></span></li><li><span><a href="#Sorting-DataFrames" data-toc-modified-id="Sorting-DataFrames-2.11"><span class="toc-item-num">2.11&nbsp;&nbsp;</span>Sorting <code>DataFrame</code>s</a></span></li></ul></li><li><span><a href="#Exercises" data-toc-modified-id="Exercises-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Exercises</a></span><ul class="toc-item"><li><span><a href="#GapMinder" data-toc-modified-id="GapMinder-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>GapMinder</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Help With `jupyter` (`ipython`) Notebooks

# %% [markdown]
# - _command_ and _edit_ modes
# - *command*: affects the structure of the notebook; *edit*: the content of a cell.
# - `H` gives a key-binding overview for both modes.
# - `Esc` bring one back from _edit_ to _command_ mode.
# - `Shift+Enter` evaluates the content of a cell.
# - `M` makes a cell of the type _Markdown_ (for a lightweight-formatted text); `Y` changes it to code
# - `A` create a new cell above the current one; `B`, below
# - an overview of the Markdown syntax [here](https://guides.github.com/features/mastering-markdown/).

# %% [markdown]
# # A Quick Run-Through Of Pandas

# %% [markdown]
# ## The Preamble

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Loading and Having a Quick Peak Into a Dataset

# %%
gm_df = pd.read_csv('gapminder.tsv', sep='\t')

# %%
# a quick look
gm_df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
# show the `n` top rows (for a quick check of the dataset)
gm_df.head(3)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710

# %%
gm_df.sample(n=4)
# Out:
#         country continent  year  lifeExp       pop     gdpPercap
# 1027    Morocco    Africa  1987   62.677  22987397   2755.046991
# 1146     Norway    Europe  1982   75.970   4114787  26298.635310
# 68    Australia   Oceania  1992   77.560  17481977  23424.766830
# 1491      Syria      Asia  1967   53.655   5680812   1881.923632

# %%
gm_df.tail(10)
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1694  Zimbabwe    Africa  1962   52.358   4277736  527.272182
# 1695  Zimbabwe    Africa  1967   53.995   4995432  569.795071
# 1696  Zimbabwe    Africa  1972   55.635   5861135  799.362176
# 1697  Zimbabwe    Africa  1977   57.674   6642107  685.587682
# 1698  Zimbabwe    Africa  1982   60.363   7636524  788.855041
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %%
gm_df
# Out:
#           country continent  year  lifeExp       pop    gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333   779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460   739.981106
# 5     Afghanistan      Asia  1977   38.438  14880372   786.113360
# 6     Afghanistan      Asia  1982   39.854  12881816   978.011439
# 7     Afghanistan      Asia  1987   40.822  13867957   852.395945
# 8     Afghanistan      Asia  1992   41.674  16317921   649.341395
# 9     Afghanistan      Asia  1997   41.763  22227415   635.341351
# 10    Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11    Afghanistan      Asia  2007   43.828  31889923   974.580338
# 12        Albania    Europe  1952   55.230   1282697  1601.056136
# ...

# %%
gm_df.shape
# Out:
# (1704, 6)

# %%
len(gm_df)
# Out:
# 1704

# %%
len(gm_df['country'].unique())
# Out:
# 142

# %%
gm_df['pop'].describe()
# Out:
# count    1.704000e+03
# mean     2.960121e+07
# std      1.061579e+08
# min      6.001100e+04
# 25%      2.793664e+06
# 50%      7.023596e+06
# 75%      1.958522e+07
# max      1.318683e+09
# Name: pop, dtype: float64

# %%
gm_df.loc[976]
# Out:
# country      Mauritius
# continent       Africa
# year              1972
# lifeExp         62.944
# pop             851334
# gdpPercap      2575.48
# Name: 976, dtype: object

# %%
gm_df.loc[976, 'pop']
# Out:
# 851334

# %%
gm_df.loc[ 976, ['pop','country'] ]
# Out:
# pop           851334
# country    Mauritius
# Name: 976, dtype: object

# %%
gm_df.loc[ [976,1000], ['pop','country'] ]
# Out:
#           pop    country
# 976    851334  Mauritius
# 1000  1320500   Mongolia

# %%
gm_df.loc[ 0:9, ['pop','country'] ]
# Out:
#         pop      country
# 0   8425333  Afghanistan
# 1   9240934  Afghanistan
# 2  10267083  Afghanistan
# 3  11537966  Afghanistan
# 4  13079460  Afghanistan
# 5  14880372  Afghanistan
# 6  12881816  Afghanistan
# 7  13867957  Afghanistan
# 8  16317921  Afghanistan
# 9  22227415  Afghanistan

# %%
gm_df.loc[ 0:5, 'year':'gdpPercap' ]
# Out:
#    year  lifeExp       pop   gdpPercap
# 0  1952   28.801   8425333  779.445314
# 1  1957   30.332   9240934  820.853030
# 2  1962   31.997  10267083  853.100710
# 3  1967   34.020  11537966  836.197138
# 4  1972   36.088  13079460  739.981106
# 5  1977   38.438  14880372  786.113360

# %% [markdown]
# write and expresision using '.loc' that produces a subset of 'gm_df' concerning the rows '1, 1000, 1500' and columns 'continent', 'country' amd 'pop,

# %%
gm_df.loc[ [1,1000,1500] , ['continent','country','pop'] ]
# Out:
#      continent      country      pop
# 1         Asia  Afghanistan  9240934
# 1000      Asia     Mongolia  1320500
# 1500      Asia       Taiwan  8550362

# %% [markdown]
# how to return the 'pop' and 'gdpPercap' of the last five rows

# %%
gm_df.loc[ len(gm_df)-5:len(gm_df) , 'pop':'gdpPercap' ]
# Out:
#            pop   gdpPercap
# 1699   9216418  706.157306
# 1700  10704340  693.420786
# 1701  11404948  792.449960
# 1702  11926563  672.038623
# 1703  12311143  469.709298

# %%
result_rows = gm_df.tail()
result_rows[['pop','gdpPercap']]
# Out:
#            pop   gdpPercap
# 1699   9216418  706.157306
# 1700  10704340  693.420786
# 1701  11404948  792.449960
# 1702  11926563  672.038623
# 1703  12311143  469.709298

# %%
result_rows = gm_df.tail()
result_rows.loc[:,['pop','gdpPercap']]
# Out:
#            pop   gdpPercap
# 1699   9216418  706.157306
# 1700  10704340  693.420786
# 1701  11404948  792.449960
# 1702  11926563  672.038623
# 1703  12311143  469.709298

# %% [markdown]
# #comments begin with a #hashtag

# %%
gm_df['pop'].describe()
# Out:
# count    1.704000e+03
# mean     2.960121e+07
# std      1.061579e+08
# min      6.001100e+04
# 25%      2.793664e+06
# 50%      7.023596e+06
# 75%      1.958522e+07
# max      1.318683e+09
# Name: pop, dtype: float64

# %%
gm_df['pop'].mean()
# Out:
# 29601212.324530516

# %%
gm_df.loc[gm_df['pop'] > gm_df['pop'].mean()].head()
# Out:
#         country continent  year  lifeExp       pop    gdpPercap
# 11  Afghanistan      Asia  2007   43.828  31889923   974.580338
# 34      Algeria    Africa  2002   70.994  31287142  5288.040382
# 35      Algeria    Africa  2007   72.301  33333216  6223.367465
# 55    Argentina  Americas  1987   70.774  31620918  9139.671389
# 56    Argentina  Americas  1992   71.868  33958947  9308.418710

# %%
gm_df.loc[gm_df['year'] == 2007].head()
# Out:
#         country continent  year  lifeExp       pop     gdpPercap
# 11  Afghanistan      Asia  2007   43.828  31889923    974.580338
# 23      Albania    Europe  2007   76.423   3600523   5937.029526
# 35      Algeria    Africa  2007   72.301  33333216   6223.367465
# 47       Angola    Africa  2007   42.731  12420476   4797.231267
# 59    Argentina  Americas  2007   75.320  40301927  12779.379640

# %%
gm_2007_df = gm_df.loc[
            ( gm_df['pop'] > gm_df['pop'].mean() ) 
            & 
            ( gm_df['year'] == 2007 )
    
         ].head()

# %%
gm_2007_df.head()
# Out:
#          country continent  year  lifeExp        pop     gdpPercap
# 11   Afghanistan      Asia  2007   43.828   31889923    974.580338
# 35       Algeria    Africa  2007   72.301   33333216   6223.367465
# 59     Argentina  Americas  2007   75.320   40301927  12779.379640
# 107   Bangladesh      Asia  2007   64.062  150448339   1391.253792
# 179       Brazil  Americas  2007   72.390  190010647   9065.800825

# %%
#gm_2007_df = gm_df.loc[( gm_df['year'] == 2007 )]

# %%
gm_2007_df['pop'].quantile(0.99)
# Out:
# 188428154.68

# %%
gm_2007_df.loc[
    gm_2007_df['pop'] >= gm_2007_df['pop'].quantile(0.95) 
].sort_values('pop', ascending=False)
# Out:
#     country continent  year  lifeExp        pop    gdpPercap
# 179  Brazil  Americas  2007    72.39  190010647  9065.800825

# %%
gm_df['year'] == 2007
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11       True
# 12      False
# 13      False
# 14      False
# 15      False
# 16      False
# 17      False
# 18      False
# 19      False
# 20      False
# 21      False
# 22      False
# 23       True
# 24      False
# 25      False
# 26      False
# 27      False
# 28      False
# 29      False
#         ...
# 1674    False
# 1675    False
# 1676    False
# 1677    False
# 1678    False
# 1679     True
# 1680    False
# 1681    False
# 1682    False
# 1683    False
# 1684    False
# 1685    False
# 1686    False
# 1687    False
# 1688    False
# 1689    False
# 1690    False
# 1691     True
# 1692    False
# 1693    False
# 1694    False
# 1695    False
# 1696    False
# 1697    False
# 1698    False
# 1699    False
# 1700    False
# 1701    False
# 1702    False
# 1703     True
# ...

# %%
gm_df.loc[ gm_df['year'] == 2007]
# Out:
#                        country continent  year  lifeExp         pop  \
# 11                 Afghanistan      Asia  2007   43.828    31889923
# 23                     Albania    Europe  2007   76.423     3600523
# 35                     Algeria    Africa  2007   72.301    33333216
# 47                      Angola    Africa  2007   42.731    12420476
# 59                   Argentina  Americas  2007   75.320    40301927
# 71                   Australia   Oceania  2007   81.235    20434176
# 83                     Austria    Europe  2007   79.829     8199783
# 95                     Bahrain      Asia  2007   75.635      708573
# 107                 Bangladesh      Asia  2007   64.062   150448339
# 119                    Belgium    Europe  2007   79.441    10392226
# 131                      Benin    Africa  2007   56.728     8078314
# 143                    Bolivia  Americas  2007   65.554     9119152
# 155     Bosnia and Herzegovina    Europe  2007   74.852     4552198
# ...

# %% [markdown]
# ## Schema, Structure, Datatypes, Distribution

# %%
gm_df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
gm_df.dtypes
# Out:
# country       object
# continent     object
# year           int64
# lifeExp      float64
# pop            int64
# gdpPercap    float64
# dtype: object

# %%
# columns and some statistics about the data distribution (numeric, by default)
gm_df.describe(include='all')
# Out:
#        country continent        year      lifeExp           pop      gdpPercap
# count     1704      1704  1704.00000  1704.000000  1.704000e+03    1704.000000
# unique     142         5         NaN          NaN           NaN            NaN
# top       Chad    Africa         NaN          NaN           NaN            NaN
# freq        12       624         NaN          NaN           NaN            NaN
# mean       NaN       NaN  1979.50000    59.474439  2.960121e+07    7215.327081
# std        NaN       NaN    17.26533    12.917107  1.061579e+08    9857.454543
# min        NaN       NaN  1952.00000    23.599000  6.001100e+04     241.165877
# 25%        NaN       NaN  1965.75000    48.198000  2.793664e+06    1202.060309
# 50%        NaN       NaN  1979.50000    60.712500  7.023596e+06    3531.846989
# 75%        NaN       NaN  1993.25000    70.845500  1.958522e+07    9325.462346
# max        NaN       NaN  2007.00000    82.603000  1.318683e+09  113523.132900

# %% [markdown]
# ## `numpy` Is Behind The Scenes

# %%
gm_df.values
# Out:
# array([['Afghanistan', 'Asia', 1952, 28.801, 8425333, 779.4453145],
#        ['Afghanistan', 'Asia', 1957, 30.331999999999997, 9240934,
#         820.8530296],
#        ['Afghanistan', 'Asia', 1962, 31.997, 10267083, 853.1007099999999],
#        ...,
#        ['Zimbabwe', 'Africa', 1997, 46.809, 11404948, 792.4499602999999],
#        ['Zimbabwe', 'Africa', 2002, 39.989000000000004, 11926563,
#         672.0386227000001],
#        ['Zimbabwe', 'Africa', 2007, 43.486999999999995, 12311143,
#         469.70929810000007]], dtype=object)

# %% [markdown]
# ## Index, Row and Column Labels

# %%
# the row index. In this case, created automatically (a range of integers)
gm_df.index
# Out:
# RangeIndex(start=0, stop=1704, step=1)

# %%
# a quick example of how to select a row based on its label
# by default, a single row is returned as `Series` object.
# More on `Series` later
gm_df.loc[4]
# Out:
# country      Afghanistan
# continent           Asia
# year                1972
# lifeExp           36.088
# pop             13079460
# gdpPercap        739.981
# Name: 4, dtype: object

# %%
row = gm_df.loc[4]
row
# Out:
# country      Afghanistan
# continent           Asia
# year                1972
# lifeExp           36.088
# pop             13079460
# gdpPercap        739.981
# Name: 4, dtype: object

# %%
type(row)
# Out:
# pandas.core.series.Series

# %%
# a list of labels (containing one element, if you'd like) will produce
# a DataFrame as a result
gm_df.loc[ [4] ]
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
# checking that it matches the expected row
gm_df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
# a DataFrame also has a column index, as we saw earlier
gm_df.columns
# Out:
# Index(['country', 'continent', 'year', 'lifeExp', 'pop', 'gdpPercap'], dtype='object')

# %%
# a single column produced by `[]`, identified by its label, is a `Series`
gm_df['country'].head()
# Out:
# 0    Afghanistan
# 1    Afghanistan
# 2    Afghanistan
# 3    Afghanistan
# 4    Afghanistan
# Name: country, dtype: object

# %%
gm_df['pop'].head()
# Out:
# 0     8425333
# 1     9240934
# 2    10267083
# 3    11537966
# 4    13079460
# Name: pop, dtype: int64

# %%
# a subset of columns (producing a DataFrame)
gm_df[ [ 'country', 'year' ] ].head()
# Out:
#        country  year
# 0  Afghanistan  1952
# 1  Afghanistan  1957
# 2  Afghanistan  1962
# 3  Afghanistan  1967
# 4  Afghanistan  1972

# %% [markdown]
# ## Just A Quick Look At The Data?

# %%
gm_df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %%
gm_df.sample(5)
# Out:
#                  country continent  year  lifeExp       pop     gdpPercap
# 1342              Serbia    Europe  2002   73.213  10111559   7236.075251
# 230             Cameroon    Africa  1962   42.643   5793633   1399.607441
# 1458           Swaziland    Africa  1982   55.561    649901   3895.384018
# 858               Kuwait      Asia  1982   71.309   1497494  31354.035730
# 1656  West Bank and Gaza      Asia  1952   43.160   1030585   1515.592329

# %%
gm_df.tail()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 1699  Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700  Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701  Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702  Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703  Zimbabwe    Africa  2007   43.487  12311143  469.709298

# %% [markdown]
# ## A Smaller, Simpler Example: `DataFrame`s From Dictionaries

# %% [markdown]
# ### Starting With A `Series` Object

# %%
# this creates a Series (see Python Data Science Handbook)
# it associates US states to areas (squared Km?)
# Notice that the argument passed to the Series creation is a
# normal Python dictionary (with 5 entries (i.e., key-value pairs))
# the keys are strings (names of states) and the values are integers
# representing the areas of those states
area = pd.Series({'California': 423967, 'Texas': 695662,
                  'New York': 141297, 'Florida': 170312,
                  'Illinois': 149995})
area
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# dtype: int64

# %% [markdown]
# ### A Quick Look At `Series`

# %%
# a `Series` object is `Pandas` version of a more interesting dictionary
# what can I do with it?

# %%
# a range (alphanumeric)
area.loc['California':'Illinois']
# Out:
# California    423967
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# dtype: int64

# %%
# a range based on position (half-closed interval: [a, b))
area.iloc[0:2]
# Out:
# California    423967
# Texas         695662
# dtype: int64

# %%
# a single value
area['California']
# Out:
# 423967

# %%
# in-place modification as expected
area['California'] = 423960
area['California']
# Out:
# 423960

# %%
# importantly, it has an `Index`
area.index
# Out:
# Index(['California', 'Texas', 'New York', 'Florida', 'Illinois'], dtype='object')

# %% [markdown]
# ### Another `Series`

# %%
# this Series contains the population numbers in each state.
# Notice that the index is the same as `area`
pop = pd.Series({'California': 38332521, 'Texas': 26448193,
                 'New York': 19651127, 'Florida': 19552860,
                 'Illinois': 12882135})

# %%
pop
# Out:
# California    38332521
# Texas         26448193
# New York      19651127
# Florida       19552860
# Illinois      12882135
# dtype: int64

# %%
pop.index
# Out:
# Index(['California', 'Texas', 'New York', 'Florida', 'Illinois'], dtype='object')

# %% [markdown]
# ### A `DataFrame` From A Set Of `Series` Objects

# %%
# instantiates a DataFrame with the columns, each associated with
# the two previous Series on area and population of US states
# They share an index, so we should have a DataFrame with 
# 5 rows and 2 columns
df = pd.DataFrame({'area':area, 'pop':pop})
df
# Out:
#               area       pop
# California  423960  38332521
# Texas       695662  26448193
# New York    141297  19651127
# Florida     170312  19552860
# Illinois    149995  12882135

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# each row is a Series, and they all share the same (column) index
df.loc['California']
# Out:
# area      423960
# pop     38332521
# Name: California, dtype: int64

# %%
df.loc['California'].index
# Out:
# Index(['area', 'pop'], dtype='object')

# %%
type(df.loc['California'].index)
# Out:
# pandas.core.indexes.base.Index

# %%
df.loc['Florida']
# Out:
# area      170312
# pop     19552860
# Name: Florida, dtype: int64

# %%
df.loc['Florida'].index is df.loc['California'].index
# Out:
# True

# %%
type(df.loc['Florida'])
# Out:
# pandas.core.series.Series

# %%
# ...and each column is a Series, and they all share the same (row) index
df['area']
# Out:
# California    423960
# Texas         695662
# New York      141297
# Florida       170312
# Illinois      149995
# Name: area, dtype: int64

# %%
df['area'].index
# Out:
# Index(['California', 'Texas', 'New York', 'Florida', 'Illinois'], dtype='object')

# %%
df['area'].index is df['pop'].index
# Out:
# True

# %% [markdown]
# ## Indexing `DataFrame`s

# %%
# different ways... My suggestion is try to stick to `.loc` as much as
# possible.
# Reasons? Consistency; views rather than copies; select on both
# rows and columns
df.loc['Illinois']
# Out:
# area      149995
# pop     12882135
# Name: Illinois, dtype: int64

# %%
df
# Out:
#               area       pop
# California  423960  38332521
# Texas       695662  26448193
# New York    141297  19651127
# Florida     170312  19552860
# Illinois    149995  12882135

# %%
df.loc['California':'Illinois']
# Out:
#               area       pop
# California  423960  38332521
# Texas       695662  26448193
# New York    141297  19651127
# Florida     170312  19552860
# Illinois    149995  12882135

# %%
df.loc['Illinois':, ['pop']]
# Out:
#                pop
# Illinois  12882135

# %%
df.loc[:, ['pop']]
# Out:
#                  pop
# California  38332521
# Texas       26448193
# New York    19651127
# Florida     19552860
# Illinois    12882135

# %%
df.loc[:, ['pop']]
# Out:
#                  pop
# California  38332521
# Texas       26448193
# New York    19651127
# Florida     19552860
# Illinois    12882135

# %%
df.loc['Florida', 'area']
# Out:
# 170312

# %% [markdown]
# ## Size and Shape

# %%
len(df)
# Out:
# 5

# %%
df.shape
# Out:
# (5, 2)

# %%
df.size
# Out:
# 10

# %% [markdown]
# ## Boolean Masks

# %%
# just like `numpy`
df['pop'] >= 20000000
# Out:
# California     True
# Texas          True
# New York      False
# Florida       False
# Illinois      False
# Name: pop, dtype: bool

# %%
df.loc[ df['pop'] >= 20000000 ]
# Out:
#               area       pop
# California  423960  38332521
# Texas       695662  26448193

# %%
# I'd rather work with millions of people..
# Example of vectorisation
df.loc[:, 'pop'] = df.loc[:, 'pop'] / 1000000
df
# Out:
#               area        pop
# California  423960  38.332521
# Texas       695662  26.448193
# New York    141297  19.651127
# Florida     170312  19.552860
# Illinois    149995  12.882135

# %%
df.loc[ df['pop'] >= 20 ]
# Out:
#               area        pop
# California  423960  38.332521
# Texas       695662  26.448193

# %%
# combining boolean arrays with & and | (use brackets)
df.loc[ (df['pop'] >= 20) & (df['area'] >= 500000) ]
# Out:
#          area        pop
# Texas  695662  26.448193

# %% [markdown]
# ## Sorting `DataFrame`s

# %%
df.sort_values?

# %%
df.sort_values(by='pop', ascending=False)
# Out:
#               area        pop
# California  423960  38.332521
# Texas       695662  26.448193
# New York    141297  19.651127
# Florida     170312  19.552860
# Illinois    149995  12.882135

# %%
# could add `inplace` for modification; otherwise, produces a new DataFrame
df.sort_values(by='area', ascending=False)
# Out:
#               area        pop
# Texas       695662  26.448193
# California  423960  38.332521
# Florida     170312  19.552860
# Illinois    149995  12.882135
# New York    141297  19.651127

# %%
# sorts the rows based on their index
df.sort_index(ascending=False)
# Out:
#               area        pop
# Texas       695662  26.448193
# New York    141297  19.651127
# Illinois    149995  12.882135
# Florida     170312  19.552860
# California  423960  38.332521

# %%
df
# Out:
#               area        pop
# California  423960  38.332521
# Texas       695662  26.448193
# New York    141297  19.651127
# Florida     170312  19.552860
# Illinois    149995  12.882135

# %% [markdown]
# # Exercises

# %%
# as a reminder, this is the DataFrame we are working with
gm_df.head()
# Out:
#        country continent  year  lifeExp       pop   gdpPercap
# 0  Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1  Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2  Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3  Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4  Afghanistan      Asia  1972   36.088  13079460  739.981106

# %% [markdown]
# ## GapMinder

# %%
# select only the observations concerning the year of 1972
gm_1972_df = gm_df.loc[ gm_df['year']==1972 ]
gm_1972_df
# Out:
#                        country continent  year   lifeExp        pop  \
# 4                  Afghanistan      Asia  1972  36.08800   13079460
# 16                     Albania    Europe  1972  67.69000    2263554
# 28                     Algeria    Africa  1972  54.51800   14760787
# 40                      Angola    Africa  1972  37.92800    5894858
# 52                   Argentina  Americas  1972  67.06500   24779799
# 64                   Australia   Oceania  1972  71.93000   13177000
# 76                     Austria    Europe  1972  70.63000    7544201
# 88                     Bahrain      Asia  1972  63.30000     230800
# 100                 Bangladesh      Asia  1972  45.25200   70759295
# 112                    Belgium    Europe  1972  71.44000    9709100
# 124                      Benin    Africa  1972  47.01400    2761407
# 136                    Bolivia  Americas  1972  46.71400    4565872
# 148     Bosnia and Herzegovina    Europe  1972  67.45000    3819000
# ...

# %%
# for the query above, how many observations are there?
len(gm_1972_df)
# Out:
# 142

# %%
gm_1972_df.shape
# Out:
# (142, 6)

# %%
# select the rows for Brazil only
gm_df.loc[ gm_df['country']=='Brazil' ]
# Out:
#     country continent  year  lifeExp        pop    gdpPercap
# 168  Brazil  Americas  1952   50.917   56602560  2108.944355
# 169  Brazil  Americas  1957   53.285   65551171  2487.365989
# 170  Brazil  Americas  1962   55.665   76039390  3336.585802
# 171  Brazil  Americas  1967   57.632   88049823  3429.864357
# 172  Brazil  Americas  1972   59.504  100840058  4985.711467
# 173  Brazil  Americas  1977   61.489  114313951  6660.118654
# 174  Brazil  Americas  1982   63.336  128962939  7030.835878
# 175  Brazil  Americas  1987   65.205  142938076  7807.095818
# 176  Brazil  Americas  1992   67.057  155975974  6950.283021
# 177  Brazil  Americas  1997   69.388  168546719  7957.980824
# 178  Brazil  Americas  2002   71.006  179914212  8131.212843
# 179  Brazil  Americas  2007   72.390  190010647  9065.800825

# %%
# what are the years for which observations have been recorded for?
gm_years_df = gm_df['year'].unique()
gm_years_df
# Out:
# array([1952, 1957, 1962, 1967, 1972, 1977, 1982, 1987, 1992, 1997, 2002,
#        2007], dtype=int64)

# %%
gm_df['year'].value_counts().sort_index()
# Out:
# 1952    142
# 1957    142
# 1962    142
# 1967    142
# 1972    142
# 1977    142
# 1982    142
# 1987    142
# 1992    142
# 1997    142
# 2002    142
# 2007    142
# Name: year, dtype: int64

# %%
# ...and how many?
len(gm_years_df)
# Out:
# 12

# %%
# what are the top 10 countries, for 2007, with regards to life expectancy?
gm_2007_df = gm_df.loc[gm_df['year']==2007]
#the commented 2 rows are for top 10 percent
#gm_2007_df = gm_2007_df.sort_values('lifeExp', ascending=False)
#gm_2007_df.head( int(len(gm_2007_df)/10) )
gm_2007_df.sort_values('lifeExp', ascending=False).head(10)
# Out:
#                country continent  year  lifeExp        pop    gdpPercap
# 803              Japan      Asia  2007   82.603  127467972  31656.06806
# 671   Hong Kong, China      Asia  2007   82.208    6980412  39724.97867
# 695            Iceland    Europe  2007   81.757     301931  36180.78919
# 1487       Switzerland    Europe  2007   81.701    7554661  37506.41907
# 71           Australia   Oceania  2007   81.235   20434176  34435.36744
# 1427             Spain    Europe  2007   80.941   40448191  28821.06370
# 1475            Sweden    Europe  2007   80.884    9031088  33859.74835
# 767             Israel      Asia  2007   80.745    6426679  25523.27710
# 539             France    Europe  2007   80.657   61083916  30470.01670
# 251             Canada  Americas  2007   80.653   33390141  36319.23501

# %%
# select the observations for Asia for the period of 2007
gm_2007_df.loc[ gm_df['continent']=='Asia' ]
# Out:
#                  country continent  year  lifeExp         pop     gdpPercap
# 11           Afghanistan      Asia  2007   43.828    31889923    974.580338
# 95               Bahrain      Asia  2007   75.635      708573  29796.048340
# 107           Bangladesh      Asia  2007   64.062   150448339   1391.253792
# 227             Cambodia      Asia  2007   59.723    14131858   1713.778686
# 299                China      Asia  2007   72.961  1318683096   4959.114854
# 671     Hong Kong, China      Asia  2007   82.208     6980412  39724.978670
# 707                India      Asia  2007   64.698  1110396331   2452.210407
# 719            Indonesia      Asia  2007   70.650   223547000   3540.651564
# 731                 Iran      Asia  2007   70.964    69453570  11605.714490
# 743                 Iraq      Asia  2007   59.545    27499638   4471.061906
# 767               Israel      Asia  2007   80.745     6426679  25523.277100
# ...

# %%
gm_df.loc[
    
    (gm_df['continent']=='Asia') & 
    (gm_df['year']==2007)
    
]
# Out:
#                  country continent  year  lifeExp         pop     gdpPercap
# 11           Afghanistan      Asia  2007   43.828    31889923    974.580338
# 95               Bahrain      Asia  2007   75.635      708573  29796.048340
# 107           Bangladesh      Asia  2007   64.062   150448339   1391.253792
# 227             Cambodia      Asia  2007   59.723    14131858   1713.778686
# 299                China      Asia  2007   72.961  1318683096   4959.114854
# 671     Hong Kong, China      Asia  2007   82.208     6980412  39724.978670
# 707                India      Asia  2007   64.698  1110396331   2452.210407
# 719            Indonesia      Asia  2007   70.650   223547000   3540.651564
# 731                 Iran      Asia  2007   70.964    69453570  11605.714490
# 743                 Iraq      Asia  2007   59.545    27499638   4471.061906
# 767               Israel      Asia  2007   80.745     6426679  25523.277100
# ...

# %%
# select the observations for South America for the period of 2000 to 2009
gm_df.loc[ 
        (gm_df['continent']=='Americas') &
        (gm_df['year']<=2009) &
        (gm_df['year']>=2000) 
         ]
#there is no South America under continents, so I used Americas
# Out:
#                   country continent  year  lifeExp        pop     gdpPercap
# 58              Argentina  Americas  2002   74.340   38331121   8797.640716
# 59              Argentina  Americas  2007   75.320   40301927  12779.379640
# 142               Bolivia  Americas  2002   63.883    8445134   3413.262690
# 143               Bolivia  Americas  2007   65.554    9119152   3822.137084
# 178                Brazil  Americas  2002   71.006  179914212   8131.212843
# 179                Brazil  Americas  2007   72.390  190010647   9065.800825
# 250                Canada  Americas  2002   79.770   31902268  33328.965070
# 251                Canada  Americas  2007   80.653   33390141  36319.235010
# 286                 Chile  Americas  2002   77.860   15497046  10778.783850
# 287                 Chile  Americas  2007   78.553   16284741  13171.638850
# 310              Colombia  Americas  2002   71.682   41008227   5755.259962
# ...

# %%
gm_df['continent'].value_counts()
# Out:
# Africa      624
# Asia        396
# Europe      360
# Americas    300
# Oceania      24
# Name: continent, dtype: int64

# %%
gm_2007_df['continent'].value_counts()
# Out:
# Africa      52
# Asia        33
# Europe      30
# Americas    25
# Oceania      2
# Name: continent, dtype: int64

# %%
# show life expectancy and GDP per capita for Brazil
gm_Brazil_df = gm_df.loc[gm_df['country']=='Brazil']
gm_Brazil_df[['lifeExp','gdpPercap']]
#gm_df.loc[gm_df['country']=='Brazil', ['lifeExp','gdpPercap'] ]
# Out:
#      lifeExp    gdpPercap
# 168   50.917  2108.944355
# 169   53.285  2487.365989
# 170   55.665  3336.585802
# 171   57.632  3429.864357
# 172   59.504  4985.711467
# 173   61.489  6660.118654
# 174   63.336  7030.835878
# 175   65.205  7807.095818
# 176   67.057  6950.283021
# 177   69.388  7957.980824
# 178   71.006  8131.212843
# 179   72.390  9065.800825

# %%
max_year=gm_Brazil_df['year'].max()
gm_Brazil_df.loc[gm_Brazil_df['year'] == max_year][['year','lifeExp','gdpPercap']]
# Out:
#      year  lifeExp    gdpPercap
# 179  2007    72.39  9065.800825

# %%
# how many observations for each continent?
gm_df['continent'].value_counts()
# Out:
# Africa      624
# Asia        396
# Europe      360
# Americas    300
# Oceania      24
# Name: continent, dtype: int64

# %%
# what is the life expectancy for Brazil measured in 2007?
gm_Brazil_df.loc[gm_Brazil_df['year'] == 2007, 'lifeExp'].iloc[0]
# Out:
# 72.39
