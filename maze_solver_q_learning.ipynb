# %%
import numpy as np
import matplotlib.pyplot as plt

#It would be useful (not mandatory) for your learning and for your thesis if you could represent the paths 
#taken by the agent graphically, perhaps at different stages of the learning. 
#One thing that is essential is for you to track the reward function, q values, and any other game parameters, 
#like how many steps it takes your agent to reach the goal.

# %%
#define actions
#actions: 0 = up, 1 = right, 2 = down, 3 = left
actions = ['up', 'right', 'down', 'left']

# %%
#define a function that determines if the specified location is a terminal state (terminal state meaning a wall)
def is_terminal_state(current_row_index, current_column_index):
  if rewards[current_row_index, current_column_index] == -1.:
    return False
  else:
    return True

#define a function that will choose a random, non-terminal starting location
def get_starting_location():
  current_row_index = np.random.randint(environment_rows)
  current_column_index = np.random.randint(environment_columns)
  #make sure that the chosen state isn't a terminal state
  while is_terminal_state(current_row_index, current_column_index):
    current_row_index = np.random.randint(environment_rows)
    current_column_index = np.random.randint(environment_columns)
  return current_row_index, current_column_index

#define an epsilon greedy algorithm that will choose which action to take next (i.e., where to move next)
def get_next_action(current_row_index, current_column_index, epsilon):
  #if a randomly chosen value between 0 and 1 is less than epsilon, 
  #then choose the most promising value from the Q-table for this state.(i.e. explotation)
  if np.random.random() < epsilon:
    return np.argmax(q_values[current_row_index, current_column_index])
  else: #choose a random action(i.e. exploration)
    return np.random.randint(4)

#define a function that will get the next location based on the chosen action
def get_next_location(current_row_index, current_column_index, action_index):
  new_row_index = current_row_index
  new_column_index = current_column_index
  if actions[action_index] == 'up' and current_row_index > 0:
    new_row_index -= 1
  elif actions[action_index] == 'right' and current_column_index < environment_columns - 1:
    new_column_index += 1
  elif actions[action_index] == 'down' and current_row_index < environment_rows - 1:
    new_row_index += 1
  elif actions[action_index] == 'left' and current_column_index > 0:
    new_column_index -= 1
  return new_row_index, new_column_index

#Define a function that will get the shortest path between any location and the exit
def get_shortest_path(start_row_index, start_column_index):
  #return immediately if this is an invalid starting location
  if is_terminal_state(start_row_index, start_column_index):
    return []
  else: #if this is a 'legal' starting location
    current_row_index, current_column_index = start_row_index, start_column_index
    shortest_path = []
    shortest_path.append([current_row_index, current_column_index])
    #continue moving along the path until we reach the goal
    while not is_terminal_state(current_row_index, current_column_index):
      #get the best action to take
      action_index = get_next_action(current_row_index, current_column_index, 1.)
      #move to the next location on the path, and add the new location to the list
      current_row_index, current_column_index = get_next_location(current_row_index, current_column_index, action_index)
      shortest_path.append([current_row_index, current_column_index])
      if len(shortest_path) > (environment_rows * environment_columns):
        return shortest_path
    return shortest_path


def draw_shortest_path():
    shortest_path1 = get_shortest_path(0, 3)
    shortest_path2 = get_shortest_path(0, 5)
    shortest_path3 = get_shortest_path(0, 1)

    if shortest_path1:
        #print(shortest_path1) #maze 1
        for i in shortest_path1:
            data[i[0], i[1]] = 0.4

    if shortest_path2:
        #print(shortest_path2) #maze 2
        for i in shortest_path2:
            data[i[0], i[1]] = 0.4

    if shortest_path3:
        #print(shortest_path3) #maze 3
        for i in shortest_path3:
            data[i[0], i[1]] = 0.4
        data[0][1] = 1

    plt.imshow(data, interpolation='nearest', cmap='hot')

# %% [markdown]
# MAZE 1: (imperfect maze)

# %%
#define the shape of the maze/enviroment (i.e., its states)
environment_rows = 10
environment_columns = 10

#Create a 3D numpy array to hold the current Q-values for each state and action pair: Q(s, a) 
q_values = np.zeros((environment_rows, environment_columns, 4))

#Create a 2D numpy array to hold the rewards for each state. 
#The array contains 10 rows and 10 columns (to match the shape of the environment), and each value is initialized to -100.
rewards = np.full((environment_rows, environment_columns), -100.)
rewards[9, 7] = 100. #set the reward for the exit (i.e., the goal) to 100

#define walkable locations (i.e., white squares) for rows 0 through 8
maze = {} #walkable locations in a dictionary
maze[0] = [3] #this is also the start
maze[1] = [i for i in range(1,9)]
maze[2] = [1, 6, 8]
maze[3] = [1, 2, 3, 5, 6, 8]
maze[4] = [1, 3, 5, 8]
maze[5] = [1, 2, 3, 4, 5, 7, 8]
maze[6] = [5]
maze[7] = [1, 3, 5, 8]
maze[8] = [i for i in range(1,9)]

#set the rewards for all locations (i.e., white squares)
for row_index in range(0,9):
    for column_index in maze[row_index]:
        rewards[row_index, column_index] = -1

#print rewards matrix (you can see the maze)
for row in rewards:
    print(row)

    
data = np.zeros((environment_columns, environment_rows))
for j in range(environment_rows):
    for i in range(environment_columns):
        if rewards[j][i] == -100:
            data[j][i] = 0
        else:
            data[j][i] = 1
    

plt.imshow(data, interpolation='nearest', cmap='hot')
# Out:
# [-100. -100. -100.   -1. -100. -100. -100. -100. -100. -100.]
# [-100.   -1.   -1.   -1.   -1.   -1.   -1.   -1.   -1. -100.]
# [-100.   -1. -100. -100. -100. -100.   -1. -100.   -1. -100.]
# [-100.   -1.   -1.   -1. -100.   -1.   -1. -100.   -1. -100.]
# [-100.   -1. -100.   -1. -100.   -1. -100. -100.   -1. -100.]
# [-100.   -1.   -1.   -1.   -1.   -1. -100.   -1.   -1. -100.]
# [-100. -100. -100. -100. -100.   -1. -100. -100. -100. -100.]
# [-100.   -1. -100.   -1. -100.   -1. -100. -100.   -1. -100.]
# [-100.   -1.   -1.   -1.   -1.   -1.   -1.   -1.   -1. -100.]
# [-100. -100. -100. -100. -100. -100. -100.  100. -100. -100.]

# %% [markdown]
# MAZE 2: (perfect maze)

# %%
#define the shape of the maze/enviroment (i.e., its states)
environment_rows = 11
environment_columns = 11

#Create a 3D numpy array to hold the current Q-values for each state and action pair: Q(s, a) 
q_values = np.zeros((environment_rows, environment_columns, 4))

#Create a 2D numpy array to hold the rewards for each state. 
#The array contains 10 rows and 10 columns (to match the shape of the environment), and each value is initialized to -100.
rewards = np.full((environment_rows, environment_columns), -100.)
rewards[10, 7] = 100. #set the reward for the exit (i.e., the goal) to 100

#define walkable locations (i.e., white squares) for rows 0 through 8
maze = {} #walkable locations in a dictionary
maze[0] = [5] #this is also the start
maze[1] = [1, 2, 3, 4, 5, 7, 8, 9]
maze[2] = [1, 5, 7, 9]
maze[3] = [1, 3, 4, 5, 7, 9]
maze[4] = [1, 7, 9]
maze[5] = [1, 3, 4, 5, 6, 7, 9]
maze[6] = [1, 3, 9]
maze[7] = [1, 2, 3, 4, 5, 7, 8, 9]
maze[8] = [7, 9]
maze[9] = [1, 2, 3, 4, 5, 6, 7, 9]

#set the rewards for all locations (i.e., white squares)
for row_index in range(0,10):
    for column_index in maze[row_index]:
        rewards[row_index, column_index] = -1

#print rewards matrix (you can see the maze)
for row in rewards:
    print(row)
    
data = np.zeros((environment_columns, environment_rows))
for j in range(environment_rows):
    for i in range(environment_columns):
        if rewards[j][i] == -100:
            data[j][i] = 0
        else:
            data[j][i] = 1
    

plt.imshow(data, interpolation='nearest', cmap='hot')
# Out:
# [-100. -100. -100. -100. -100.   -1. -100. -100. -100. -100. -100.]
# [-100.   -1.   -1.   -1.   -1.   -1. -100.   -1.   -1.   -1. -100.]
# [-100.   -1. -100. -100. -100.   -1. -100.   -1. -100.   -1. -100.]
# [-100.   -1. -100.   -1.   -1.   -1. -100.   -1. -100.   -1. -100.]
# [-100.   -1. -100. -100. -100. -100. -100.   -1. -100.   -1. -100.]
# [-100.   -1. -100.   -1.   -1.   -1.   -1.   -1. -100.   -1. -100.]
# [-100.   -1. -100.   -1. -100. -100. -100. -100. -100.   -1. -100.]
# [-100.   -1.   -1.   -1.   -1.   -1. -100.   -1.   -1.   -1. -100.]
# [-100. -100. -100. -100. -100. -100. -100.   -1. -100.   -1. -100.]
# [-100.   -1.   -1.   -1.   -1.   -1.   -1.   -1. -100.   -1. -100.]
# [-100. -100. -100. -100. -100. -100. -100.  100. -100. -100. -100.]

# %% [markdown]
# MAZE 3: (continuous maze)

# %%
#define the shape of the maze/enviroment (i.e., its states)
environment_rows = 11
environment_columns = 11

#Create a 3D numpy array to hold the current Q-values for each state and action pair: Q(s, a) 
q_values = np.zeros((environment_rows, environment_columns, 4))

#Create a 2D numpy array to hold the rewards for each state. 
#The array contains 10 rows and 10 columns (to match the shape of the environment), and each value is initialized to -100.
rewards = np.full((environment_rows, environment_columns), -100.)
rewards[10, 9] = 100. #set the reward for the exit (i.e., the goal) to 100

#define walkable locations (i.e., white squares) for rows 0 through 8
maze = {} #walkable locations in a dictionary
maze[0] = [1] #this is also the start
maze[1] = [1, 3, 4, 5, 6, 7, 8, 9]
maze[2] = [1, 3, 9]
maze[3] = [1, 3, 4, 5, 6, 7, 9]
maze[4] = [1, 7, 9]
maze[5] = [1, 2, 3, 4, 5, 7, 9]
maze[6] = [5, 7, 9]
maze[7] = [1, 2, 3, 4, 5, 7, 9]
maze[8] = [1, 7, 9]
maze[9] = [1, 2, 3, 4, 5, 6, 7, 9]

#set the rewards for all locations (i.e., white squares)
for row_index in range(0,10):
    for column_index in maze[row_index]:
        rewards[row_index, column_index] = -1

#print rewards matrix (you can see the maze)
for row in rewards:
    print(row)
    
data = np.zeros((environment_columns, environment_rows))
for j in range(environment_rows):
    for i in range(environment_columns):
        if rewards[j][i] == -100:
            data[j][i] = 0
        else:
            data[j][i] = 1
    

plt.imshow(data, interpolation='nearest', cmap='hot')
# Out:
# [-100.   -1. -100. -100. -100. -100. -100. -100. -100. -100. -100.]
# [-100.   -1. -100.   -1.   -1.   -1.   -1.   -1.   -1.   -1. -100.]
# [-100.   -1. -100.   -1. -100. -100. -100. -100. -100.   -1. -100.]
# [-100.   -1. -100.   -1.   -1.   -1.   -1.   -1. -100.   -1. -100.]
# [-100.   -1. -100. -100. -100. -100. -100.   -1. -100.   -1. -100.]
# [-100.   -1.   -1.   -1.   -1.   -1. -100.   -1. -100.   -1. -100.]
# [-100. -100. -100. -100. -100.   -1. -100.   -1. -100.   -1. -100.]
# [-100.   -1.   -1.   -1.   -1.   -1. -100.   -1. -100.   -1. -100.]
# [-100.   -1. -100. -100. -100. -100. -100.   -1. -100.   -1. -100.]
# [-100.   -1.   -1.   -1.   -1.   -1.   -1.   -1. -100.   -1. -100.]
# [-100. -100. -100. -100. -100. -100. -100. -100. -100.  100. -100.]

# %% [markdown]
# RUN ONE OF THE 3 MAZES AND THEN RUN THE CELL BELOW TO TRAIN THE AGENT ON THE CHOSEN MAZE

# %%
#define training parameters
discount_factor = 0.9
learning_rate = 0.9 
sampling_frequency = 10
number_of_episodes = 2000
epsilon = 0.1
epsilon_incrementor = 1/(0.9*number_of_episodes)

#image pixel data
original_data = data.copy()
data_array = np.zeros((environment_rows, environment_columns, int(number_of_episodes/sampling_frequency) ))

#metrics sotrage arrays
reward_array = []
episode_array_for_minmaxavg = []
min_reward_array = [] 
max_reward_array = []
avg_reward_array = []
number_of_steps_array = []
mean_q_values = []


for episode in range(number_of_episodes):
    #row_index, column_index = get_starting_location()    
    row_index = 0
    #column_index = 3 #maze 1
    #column_index = 5 #maze 2
    column_index = 1 #maze 3
    
    aggr_q_values = 0
    number_of_steps = 0
    aggr_reward = 0    
    
    while not is_terminal_state(row_index, column_index):
        action_index = get_next_action(row_index, column_index, epsilon)
        old_row_index, old_column_index = row_index, column_index 
        row_index, column_index = get_next_location(old_row_index, old_column_index, action_index)

        reward = rewards[row_index, column_index]
        old_q_value = q_values[old_row_index, old_column_index, action_index]
        temporal_difference = reward + (discount_factor * np.max(q_values[row_index, column_index])) - old_q_value

        new_q_value = old_q_value + (learning_rate * temporal_difference)
        q_values[old_row_index, old_column_index, action_index] = new_q_value
        
        #metrics variables-------------------------------------------------------
        aggr_reward +=reward  
        number_of_steps += 1
        aggr_q_values += new_q_value
        #------------------------------------------------------------------------
        
    if epsilon < 1:
        epsilon += epsilon_incrementor
        
    
    reward_array.append(aggr_reward)    
    number_of_steps_array.append(number_of_steps)
    if number_of_steps > 0:
        mean_q_values.append(aggr_q_values/number_of_steps)
    else:
        mean_q_values.append(0)
    
    if episode%sampling_frequency ==  0:
        index = int(episode / sampling_frequency)  
        draw_shortest_path()
        data_array[:,:,index] = data.copy()
        data = original_data.copy()
        
        average_reward = sum(reward_array[-sampling_frequency:])/sampling_frequency
        min_reward = min(reward_array[-sampling_frequency:])
        max_reward = max(reward_array[-sampling_frequency:])       
        print("Index: ", index ,", Episode: ", episode,"Rewards-- min: ", min_reward ," max: ", max_reward, " avg: ", average_reward)

        episode_array_for_minmaxavg.append(episode)
        min_reward_array.append(min_reward)
        max_reward_array.append(max_reward)
        avg_reward_array.append(average_reward)

print('Training complete!')
# Out:
# Index:  0 , Episode:  0 Rewards-- min:  -102.0  max:  -102.0  avg:  -10.2
# Index:  1 , Episode:  10 Rewards-- min:  -105.0  max:  -100.0  avg:  -101.2
# Index:  2 , Episode:  20 Rewards-- min:  -103.0  max:  -100.0  avg:  -101.2
# Index:  3 , Episode:  30 Rewards-- min:  -105.0  max:  -100.0  avg:  -100.9
# Index:  4 , Episode:  40 Rewards-- min:  -103.0  max:  -100.0  avg:  -100.5
# Index:  5 , Episode:  50 Rewards-- min:  -105.0  max:  -100.0  avg:  -101.4
# Index:  6 , Episode:  60 Rewards-- min:  -105.0  max:  -100.0  avg:  -101.4
# Index:  7 , Episode:  70 Rewards-- min:  -104.0  max:  -100.0  avg:  -100.9
# Index:  8 , Episode:  80 Rewards-- min:  -104.0  max:  -100.0  avg:  -101.5
# Index:  9 , Episode:  90 Rewards-- min:  -102.0  max:  -100.0  avg:  -100.8
# Index:  10 , Episode:  100 Rewards-- min:  -102.0  max:  -100.0  avg:  -100.7
# Index:  11 , Episode:  110 Rewards-- min:  -106.0  max:  -100.0  avg:  -101.6
# Index:  12 , Episode:  120 Rewards-- min:  -105.0  max:  -100.0  avg:  -101.5
# Index:  13 , Episode:  130 Rewards-- min:  -108.0  max:  -100.0  avg:  -102.6
# Index:  14 , Episode:  140 Rewards-- min:  -107.0  max:  -100.0  avg:  -102.1
# Index:  15 , Episode:  150 Rewards-- min:  -109.0  max:  -100.0  avg:  -102.2
# Index:  16 , Episode:  160 Rewards-- min:  -106.0  max:  -100.0  avg:  -101.6
# Index:  17 , Episode:  170 Rewards-- min:  -106.0  max:  -100.0  avg:  -101.8
# Index:  18 , Episode:  180 Rewards-- min:  -108.0  max:  -100.0  avg:  -103.0
# Index:  19 , Episode:  190 Rewards-- min:  -105.0  max:  -100.0  avg:  -101.6
# Index:  20 , Episode:  200 Rewards-- min:  -105.0  max:  -100.0  avg:  -101.1
# Index:  21 , Episode:  210 Rewards-- min:  -111.0  max:  -100.0  avg:  -102.0
# Index:  22 , Episode:  220 Rewards-- min:  -109.0  max:  -100.0  avg:  -101.5
# Index:  23 , Episode:  230 Rewards-- min:  -102.0  max:  -100.0  avg:  -100.5
# Index:  24 , Episode:  240 Rewards-- min:  -108.0  max:  -100.0  avg:  -102.2
# Index:  25 , Episode:  250 Rewards-- min:  -103.0  max:  -100.0  avg:  -100.9
# Index:  26 , Episode:  260 Rewards-- min:  -103.0  max:  -100.0  avg:  -101.1
# Index:  27 , Episode:  270 Rewards-- min:  -106.0  max:  -100.0  avg:  -102.1
# Index:  28 , Episode:  280 Rewards-- min:  -104.0  max:  -100.0  avg:  -101.0
# Index:  29 , Episode:  290 Rewards-- min:  -104.0  max:  -100.0  avg:  -101.4
# Index:  30 , Episode:  300 Rewards-- min:  -104.0  max:  -100.0  avg:  -101.7
# Index:  31 , Episode:  310 Rewards-- min:  -104.0  max:  -100.0  avg:  -101.4
# Index:  32 , Episode:  320 Rewards-- min:  -105.0  max:  -100.0  avg:  -101.3
# Index:  33 , Episode:  330 Rewards-- min:  -106.0  max:  -100.0  avg:  -101.8
# Index:  34 , Episode:  340 Rewards-- min:  -105.0  max:  -100.0  avg:  -102.4
# Index:  35 , Episode:  350 Rewards-- min:  -104.0  max:  -100.0  avg:  -101.0
# Index:  36 , Episode:  360 Rewards-- min:  -108.0  max:  -100.0  avg:  -103.0
# Index:  37 , Episode:  370 Rewards-- min:  -104.0  max:  -100.0  avg:  -101.3
# Index:  38 , Episode:  380 Rewards-- min:  -103.0  max:  -100.0  avg:  -100.9
# Index:  39 , Episode:  390 Rewards-- min:  -103.0  max:  -100.0  avg:  -100.8
# Index:  40 , Episode:  400 Rewards-- min:  -106.0  max:  -100.0  avg:  -102.1
# Index:  41 , Episode:  410 Rewards-- min:  -108.0  max:  -100.0  avg:  -102.2
# Index:  42 , Episode:  420 Rewards-- min:  -104.0  max:  -100.0  avg:  -100.9
# Index:  43 , Episode:  430 Rewards-- min:  -109.0  max:  -100.0  avg:  -102.9
# Index:  44 , Episode:  440 Rewards-- min:  -106.0  max:  -100.0  avg:  -101.9
# Index:  45 , Episode:  450 Rewards-- min:  -104.0  max:  -100.0  avg:  -101.3
# Index:  46 , Episode:  460 Rewards-- min:  -110.0  max:  -100.0  avg:  -102.4
# Index:  47 , Episode:  470 Rewards-- min:  -111.0  max:  -100.0  avg:  -102.5
# Index:  48 , Episode:  480 Rewards-- min:  -104.0  max:  -100.0  avg:  -102.1
# Index:  49 , Episode:  490 Rewards-- min:  -106.0  max:  -100.0  avg:  -101.4
# Index:  50 , Episode:  500 Rewards-- min:  -108.0  max:  -100.0  avg:  -102.0
# Index:  51 , Episode:  510 Rewards-- min:  -105.0  max:  -100.0  avg:  -102.2
# Index:  52 , Episode:  520 Rewards-- min:  -102.0  max:  -100.0  avg:  -100.6
# Index:  53 , Episode:  530 Rewards-- min:  -110.0  max:  -100.0  avg:  -103.2
# Index:  54 , Episode:  540 Rewards-- min:  -106.0  max:  -101.0  avg:  -102.7
# Index:  55 , Episode:  550 Rewards-- min:  -107.0  max:  -100.0  avg:  -103.0
# Index:  56 , Episode:  560 Rewards-- min:  -111.0  max:  -100.0  avg:  -102.5
# Index:  57 , Episode:  570 Rewards-- min:  -107.0  max:  -100.0  avg:  -101.4
# Index:  58 , Episode:  580 Rewards-- min:  -108.0  max:  -100.0  avg:  -102.8
# Index:  59 , Episode:  590 Rewards-- min:  -108.0  max:  -100.0  avg:  -102.1
# Index:  60 , Episode:  600 Rewards-- min:  -105.0  max:  -100.0  avg:  -101.7
# Index:  61 , Episode:  610 Rewards-- min:  -104.0  max:  -100.0  avg:  -100.7
# Index:  62 , Episode:  620 Rewards-- min:  -109.0  max:  -100.0  avg:  -103.4
# Index:  63 , Episode:  630 Rewards-- min:  -111.0  max:  -100.0  avg:  -102.4
# Index:  64 , Episode:  640 Rewards-- min:  -113.0  max:  -100.0  avg:  -104.5
# Index:  65 , Episode:  650 Rewards-- min:  -105.0  max:  -100.0  avg:  -101.3
# Index:  66 , Episode:  660 Rewards-- min:  -109.0  max:  -100.0  avg:  -102.2
# Index:  67 , Episode:  670 Rewards-- min:  -112.0  max:  -100.0  avg:  -103.0
# Index:  68 , Episode:  680 Rewards-- min:  -108.0  max:  -100.0  avg:  -102.4
# Index:  69 , Episode:  690 Rewards-- min:  -106.0  max:  -100.0  avg:  -103.5
# Index:  70 , Episode:  700 Rewards-- min:  -110.0  max:  -100.0  avg:  -104.3
# Index:  71 , Episode:  710 Rewards-- min:  -108.0  max:  -100.0  avg:  -102.8
# Index:  72 , Episode:  720 Rewards-- min:  -108.0  max:  -100.0  avg:  -104.2
# Index:  73 , Episode:  730 Rewards-- min:  -105.0  max:  -100.0  avg:  -102.0
# Index:  74 , Episode:  740 Rewards-- min:  -113.0  max:  -100.0  avg:  -102.0
# Index:  75 , Episode:  750 Rewards-- min:  -106.0  max:  -100.0  avg:  -101.5
# Index:  76 , Episode:  760 Rewards-- min:  -107.0  max:  -100.0  avg:  -102.6
# Index:  77 , Episode:  770 Rewards-- min:  -107.0  max:  -100.0  avg:  -102.3
# Index:  78 , Episode:  780 Rewards-- min:  -113.0  max:  -100.0  avg:  -103.3
# Index:  79 , Episode:  790 Rewards-- min:  -112.0  max:  -100.0  avg:  -103.4
# Index:  80 , Episode:  800 Rewards-- min:  -105.0  max:  -101.0  avg:  -102.7
# Index:  81 , Episode:  810 Rewards-- min:  -112.0  max:  -100.0  avg:  -105.5
# Index:  82 , Episode:  820 Rewards-- min:  -124.0  max:  -100.0  avg:  -105.1
# Index:  83 , Episode:  830 Rewards-- min:  -106.0  max:  -100.0  avg:  -102.4
# Index:  84 , Episode:  840 Rewards-- min:  -109.0  max:  -100.0  avg:  -102.5
# Index:  85 , Episode:  850 Rewards-- min:  -111.0  max:  -100.0  avg:  -104.0
# Index:  86 , Episode:  860 Rewards-- min:  -106.0  max:  -101.0  avg:  -103.4
# Index:  87 , Episode:  870 Rewards-- min:  -112.0  max:  -100.0  avg:  -104.2
# Index:  88 , Episode:  880 Rewards-- min:  -103.0  max:  -100.0  avg:  -101.4
# Index:  89 , Episode:  890 Rewards-- min:  -110.0  max:  -100.0  avg:  -104.7
# Index:  90 , Episode:  900 Rewards-- min:  -123.0  max:  -100.0  avg:  -104.1
# Index:  91 , Episode:  910 Rewards-- min:  -113.0  max:  -100.0  avg:  -103.4
# Index:  92 , Episode:  920 Rewards-- min:  -108.0  max:  -100.0  avg:  -103.2
# Index:  93 , Episode:  930 Rewards-- min:  -118.0  max:  -100.0  avg:  -104.5
# Index:  94 , Episode:  940 Rewards-- min:  -116.0  max:  -100.0  avg:  -106.5
# Index:  95 , Episode:  950 Rewards-- min:  -116.0  max:  -100.0  avg:  -104.7
# Index:  96 , Episode:  960 Rewards-- min:  -111.0  max:  -100.0  avg:  -105.1
# Index:  97 , Episode:  970 Rewards-- min:  -108.0  max:  -100.0  avg:  -102.9
# Index:  98 , Episode:  980 Rewards-- min:  -112.0  max:  -100.0  avg:  -105.4
# Index:  99 , Episode:  990 Rewards-- min:  -117.0  max:  -100.0  avg:  -104.6
# Index:  100 , Episode:  1000 Rewards-- min:  -113.0  max:  -100.0  avg:  -104.2
# Index:  101 , Episode:  1010 Rewards-- min:  -114.0  max:  -101.0  avg:  -105.7
# Index:  102 , Episode:  1020 Rewards-- min:  -123.0  max:  -100.0  avg:  -108.5
# Index:  103 , Episode:  1030 Rewards-- min:  -123.0  max:  -100.0  avg:  -108.1
# Index:  104 , Episode:  1040 Rewards-- min:  -124.0  max:  -101.0  avg:  -108.6
# Index:  105 , Episode:  1050 Rewards-- min:  -108.0  max:  -100.0  avg:  -103.7
# Index:  106 , Episode:  1060 Rewards-- min:  -119.0  max:  -100.0  avg:  -106.5
# Index:  107 , Episode:  1070 Rewards-- min:  -113.0  max:  -100.0  avg:  -105.3
# Index:  108 , Episode:  1080 Rewards-- min:  -119.0  max:  -100.0  avg:  -106.4
# Index:  109 , Episode:  1090 Rewards-- min:  -112.0  max:  -100.0  avg:  -103.6
# Index:  110 , Episode:  1100 Rewards-- min:  -115.0  max:  -100.0  avg:  -105.3
# Index:  111 , Episode:  1110 Rewards-- min:  -111.0  max:  -100.0  avg:  -104.5
# Index:  112 , Episode:  1120 Rewards-- min:  -108.0  max:  -100.0  avg:  -103.0
# Index:  113 , Episode:  1130 Rewards-- min:  -117.0  max:  -101.0  avg:  -107.4
# Index:  114 , Episode:  1140 Rewards-- min:  -125.0  max:  -100.0  avg:  -106.7
# Index:  115 , Episode:  1150 Rewards-- min:  -116.0  max:  -100.0  avg:  -105.0
# Index:  116 , Episode:  1160 Rewards-- min:  -120.0  max:  -100.0  avg:  -106.9
# Index:  117 , Episode:  1170 Rewards-- min:  -120.0  max:  -101.0  avg:  -106.5
# Index:  118 , Episode:  1180 Rewards-- min:  -124.0  max:  -100.0  avg:  -106.7
# Index:  119 , Episode:  1190 Rewards-- min:  -109.0  max:  -100.0  avg:  -103.6
# Index:  120 , Episode:  1200 Rewards-- min:  -119.0  max:  -101.0  avg:  -110.8
# Index:  121 , Episode:  1210 Rewards-- min:  -116.0  max:  -100.0  avg:  -106.6
# Index:  122 , Episode:  1220 Rewards-- min:  -114.0  max:  -100.0  avg:  -104.4
# Index:  123 , Episode:  1230 Rewards-- min:  -122.0  max:  -101.0  avg:  -108.1
# Index:  124 , Episode:  1240 Rewards-- min:  -116.0  max:  -100.0  avg:  -105.4
# Index:  125 , Episode:  1250 Rewards-- min:  -131.0  max:  -100.0  avg:  -110.6
# Index:  126 , Episode:  1260 Rewards-- min:  -122.0  max:  -100.0  avg:  -110.7
# Index:  127 , Episode:  1270 Rewards-- min:  -117.0  max:  -100.0  avg:  -107.6
# Index:  128 , Episode:  1280 Rewards-- min:  -121.0  max:  -100.0  avg:  -107.7
# Index:  129 , Episode:  1290 Rewards-- min:  -129.0  max:  -100.0  avg:  -115.2
# Index:  130 , Episode:  1300 Rewards-- min:  -119.0  max:  -100.0  avg:  -107.7
# Index:  131 , Episode:  1310 Rewards-- min:  -128.0  max:  -100.0  avg:  -107.0
# Index:  132 , Episode:  1320 Rewards-- min:  -129.0  max:  -100.0  avg:  -108.6
# Index:  133 , Episode:  1330 Rewards-- min:  -120.0  max:  -101.0  avg:  -109.1
# Index:  134 , Episode:  1340 Rewards-- min:  -123.0  max:  -100.0  avg:  -108.1
# Index:  135 , Episode:  1350 Rewards-- min:  -122.0  max:  -101.0  avg:  -108.2
# Index:  136 , Episode:  1360 Rewards-- min:  -120.0  max:  -103.0  avg:  -111.2
# Index:  137 , Episode:  1370 Rewards-- min:  -130.0  max:  -103.0  avg:  -107.5
# Index:  138 , Episode:  1380 Rewards-- min:  -120.0  max:  -100.0  avg:  -107.6
# Index:  139 , Episode:  1390 Rewards-- min:  -132.0  max:  -100.0  avg:  -111.2
# Index:  140 , Episode:  1400 Rewards-- min:  -132.0  max:  -100.0  avg:  -113.4
# Index:  141 , Episode:  1410 Rewards-- min:  -127.0  max:  -100.0  avg:  -111.8
# Index:  142 , Episode:  1420 Rewards-- min:  -137.0  max:  -102.0  avg:  -121.3
# Index:  143 , Episode:  1430 Rewards-- min:  -137.0  max:  -102.0  avg:  -115.5
# Index:  144 , Episode:  1440 Rewards-- min:  -137.0  max:  -100.0  avg:  -119.0
# Index:  145 , Episode:  1450 Rewards-- min:  -138.0  max:  -100.0  avg:  -118.5
# Index:  146 , Episode:  1460 Rewards-- min:  -139.0  max:  -101.0  avg:  -114.2
# Index:  147 , Episode:  1470 Rewards-- min:  -139.0  max:  -101.0  avg:  -112.4
# Index:  148 , Episode:  1480 Rewards-- min:  -138.0  max:  -100.0  avg:  -112.5
# Index:  149 , Episode:  1490 Rewards-- min:  -143.0  max:  -103.0  avg:  -117.9
# Index:  150 , Episode:  1500 Rewards-- min:  -145.0  max:  -103.0  avg:  -118.2
# Index:  151 , Episode:  1510 Rewards-- min:  -149.0  max:  -100.0  avg:  -126.5
# Index:  152 , Episode:  1520 Rewards-- min:  -154.0  max:  -101.0  avg:  -133.5
# Index:  153 , Episode:  1530 Rewards-- min:  -159.0  max:  -100.0  avg:  -133.2
# Index:  154 , Episode:  1540 Rewards-- min:  -160.0  max:  -107.0  avg:  -123.5
# Index:  155 , Episode:  1550 Rewards-- min:  -164.0  max:  -103.0  avg:  -134.1
# Index:  156 , Episode:  1560 Rewards-- min:  -161.0  max:  -101.0  avg:  -139.3
# Index:  157 , Episode:  1570 Rewards-- min:  -164.0  max:  -118.0  avg:  -145.7
# Index:  158 , Episode:  1580 Rewards-- min:  -165.0  max:  46.0  avg:  -121.3
# Index:  159 , Episode:  1590 Rewards-- min:  -127.0  max:  43.0  avg:  -8.6
# Index:  160 , Episode:  1600 Rewards-- min:  -134.0  max:  47.0  avg:  -56.3
# Index:  161 , Episode:  1610 Rewards-- min:  35.0  max:  47.0  avg:  42.8
# Index:  162 , Episode:  1620 Rewards-- min:  41.0  max:  49.0  avg:  45.7
# Index:  163 , Episode:  1630 Rewards-- min:  43.0  max:  51.0  avg:  47.9
# Index:  164 , Episode:  1640 Rewards-- min:  45.0  max:  51.0  avg:  49.4
# Index:  165 , Episode:  1650 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  166 , Episode:  1660 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  167 , Episode:  1670 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  168 , Episode:  1680 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  169 , Episode:  1690 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  170 , Episode:  1700 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  171 , Episode:  1710 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  172 , Episode:  1720 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  173 , Episode:  1730 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  174 , Episode:  1740 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  175 , Episode:  1750 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  176 , Episode:  1760 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  177 , Episode:  1770 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  178 , Episode:  1780 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  179 , Episode:  1790 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  180 , Episode:  1800 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  181 , Episode:  1810 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  182 , Episode:  1820 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  183 , Episode:  1830 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  184 , Episode:  1840 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  185 , Episode:  1850 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  186 , Episode:  1860 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  187 , Episode:  1870 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  188 , Episode:  1880 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  189 , Episode:  1890 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  190 , Episode:  1900 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  191 , Episode:  1910 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  192 , Episode:  1920 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  193 , Episode:  1930 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  194 , Episode:  1940 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  195 , Episode:  1950 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  196 , Episode:  1960 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  197 , Episode:  1970 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  198 , Episode:  1980 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Index:  199 , Episode:  1990 Rewards-- min:  51.0  max:  51.0  avg:  51.0
# Training complete!

# %%
fig=plt.figure(figsize=(16, 16))
columns = 10
rows = 20
for i in range(1, columns*rows +1):
    img = data_array[:,:,i-1]
    fig.add_subplot(rows, columns, i)    
    plt.imshow(img, interpolation='nearest', cmap='hot')
plt.show()

# %%
fig=plt.figure(figsize=(16, 10))
plt.plot(reward_array,  label="Reward" )
plt.ylim(-200, 100)
plt.title("Rewards per episode")
plt.legend(loc=2)
plt.show()

# %%
fig=plt.figure(figsize=(16, 10))
plt.plot(episode_array_for_minmaxavg, min_reward_array, label="Min" )
plt.plot(episode_array_for_minmaxavg, max_reward_array, label="Max" )
plt.plot(episode_array_for_minmaxavg, avg_reward_array, label="Avg" )
plt.title("Reward MIN MAX AVG per episode")
plt.ylim(-200, 100)
plt.legend(loc=2)
plt.show()

# %%
fig =plt.figure(figsize=(16, 10))
plt.plot(mean_q_values,  label="Mean Q-Value" )
plt.title("Mean Q-Values of each episodes")
plt.ylim(-150, 50)
plt.legend(loc=2)
plt.show()

# %%
fig=plt.figure(figsize=(16, 10))
plt.plot(number_of_steps_array,  label="Number of steps" )
plt.title("Number of steps per episode")
plt.ylim(-50, 100)
plt.legend(loc=2)
plt.show()

# %%
import tensorflow as tf
tf.__version__
# Out:
# '2.2.0'
