# %%
#importing requierd libraires
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np

#keras imagedatagenerator as mentioned in the 6G7Z1003 High-Performance Computing and Big Data (1CWK50) HPC TensorFlow Task (50%) (Assessment Overview)
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import TensorBoard
from datetime import datetime
import warnings
warnings.filterwarnings("ignore")
# Out:
# Using TensorFlow backend.

# %%
model = tf.keras.models.Sequential()

#input layer with 96 by 96 pixel size and 3 bits of depth representing color with max pooling which prooved to be better than strides
#without either training takes to long because there are to many parameters, followed by batch normalization and droput as advised in the (Assessment Overview)
#upon reaserch I found that droupout of 20% gives good results on Caltech-101 so I used the same dropout rate, I also used 16 filters because
#(Assessment Overview) suggested depth over number of filters, activation used is relu because it is most widely used
model.add(tf.keras.layers.Conv2D(16, (5, 5),  input_shape=(96, 96, 3) ,activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.20))
    
#1rd hidden layer, 2nd convolutional layer, with 32 filters
model.add(tf.keras.layers.Conv2D(32, (3, 3), activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.20))
    
#2th hidden layer, 3rd convolutional layer with 64 filters
model.add(tf.keras.layers.Conv2D(64, (3, 3),  activation='relu'))
model.add(tf.keras.layers.MaxPooling2D(pool_size=(2, 2)))
model.add(tf.keras.layers.BatchNormalization())
model.add(tf.keras.layers.Dropout(0.20))


#3rdhidden layer, Dense with 2x number of output, also seemed to work well on Caltech-101 so I applied it here also
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(512, activation='relu'))
model.add(tf.keras.layers.BatchNormalization())

#output, using softmax, also standard
model.add(tf.keras.layers.Dense(256, activation='softmax'))
#optimizer used is adam with categorical crossentropy, also used in Caltech-101 and found that it is most commonly recomended online, metrics measured as (Assessment Overview) requeired
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy', 'crossentropy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 92, 92, 16)        1216
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 46, 46, 16)        0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 46, 46, 16)        64
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 46, 46, 16)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 44, 44, 32)        4640
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 22, 22, 32)        0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 22, 22, 32)        128
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 22, 22, 32)        0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 20, 20, 64)        18496
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 10, 10, 64)        0
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 10, 10, 64)        256
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 10, 10, 64)        0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 6400)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 512)               3277312
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 512)               2048
# _________________________________________________________________
# dense_3 (Dense)              (None, 256)               131328
# =================================================================
# Total params: 3,435,488
# Trainable params: 3,434,240
# Non-trainable params: 1,248
# _________________________________________________________________

# %%
#images, the whole dataset i.e. the map or folder is stored in the same folder as the notebook
#input size meaning the dimentions of the picture is defined by target size
#batch size determines the amount of pictures that imagedatagenerator will generate, not on the amount of inputs that will be fitted to the NN in one step
#validation split is 0.1 10% as (Assessment Overview) requiers, epoch were set at 100 and proved to be adequate
img_path = './256_ObjectCategories/'
target_size = (96,96)
batch_size = 128
epochs = 100
steps_per_epoch = 64
validation_steps = 20
validation_split = 0.1



#devides the whole training data into test and train sets, class mode is set to categorical because the loss is categorical crossentropy, if it were sparse categorical crossentropy the calss mode woud be spars categorical
#rescale, rotation range etc.. were most common recomendations for working with Caltech-101 and Caltech-256 which I found
train_datagen = ImageDataGenerator(
        rescale=1./255,
        validation_split= validation_split,
        rotation_range=20,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.15,
        zoom_range=0.15,
        horizontal_flip=True)

test_datagen = ImageDataGenerator(
        rescale=1./255,
        validation_split= validation_split)

train_generator = train_datagen.flow_from_directory(
        img_path,
        subset = 'training',
        target_size=target_size,
        batch_size=batch_size,
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
        img_path,
        subset = 'validation',
        target_size=target_size,
        batch_size=batch_size,
        class_mode='categorical')

#following 2 lines are used for tensorboard
log_dir = "logs/" + datetime.now().strftime("%Y%m%d-%H%M%S")
tensorboard_callback = tf.keras.callbacks.TensorBoard(log_dir=log_dir)

#main training function, with batch size of 2, meaning 2 inputs are fitted to the NN at one step,... using teansorboard for callbacks
H=model.fit(
        train_generator,
        steps_per_epoch=steps_per_epoch,
        epochs=epochs,
        batch_size = 2,
        validation_data=validation_generator,
        validation_steps=validation_steps,
        callbacks=[tensorboard_callback])
# Out:
# Found 27644 images belonging to 256 classes.
# Found 2963 images belonging to 256 classes.
# Epoch 1/100
#  2/64 [..............................] - ETA: 2s - loss: 6.0958 - accuracy: 0.0039 - crossentropy: 6.0958    WARNING:tensorflow:Callbacks method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0316s vs `on_train_batch_end` time: 0.0619s). Check your callbacks.
# 64/64 [==============================] - 35s 543ms/step - loss: 5.3119 - accuracy: 0.0710 - crossentropy: 5.3119 - val_loss: 5.8139 - val_accuracy: 0.0293 - val_crossentropy: 5.8139
# Epoch 2/100
# 64/64 [==============================] - 35s 539ms/step - loss: 4.8341 - accuracy: 0.1101 - crossentropy: 4.8341 - val_loss: 6.5526 - val_accuracy: 0.0269 - val_crossentropy: 6.5526
# Epoch 3/100
# 64/64 [==============================] - 34s 531ms/step - loss: 4.6720 - accuracy: 0.1289 - crossentropy: 4.6720 - val_loss: 6.1904 - val_accuracy: 0.0253 - val_crossentropy: 6.1904
# Epoch 4/100
# 64/64 [==============================] - 37s 585ms/step - loss: 4.4217 - accuracy: 0.1503 - crossentropy: 4.4217 - val_loss: 6.3498 - val_accuracy: 0.0322 - val_crossentropy: 6.3498
# Epoch 5/100
# 64/64 [==============================] - 35s 542ms/step - loss: 4.3352 - accuracy: 0.1659 - crossentropy: 4.3352 - val_loss: 6.3609 - val_accuracy: 0.0412 - val_crossentropy: 6.3609
# Epoch 6/100
# 64/64 [==============================] - 34s 536ms/step - loss: 4.3098 - accuracy: 0.1611 - crossentropy: 4.3098 - val_loss: 5.8262 - val_accuracy: 0.0588 - val_crossentropy: 5.8262
# Epoch 7/100
# 64/64 [==============================] - 35s 543ms/step - loss: 4.2140 - accuracy: 0.1753 - crossentropy: 4.2140 - val_loss: 5.1119 - val_accuracy: 0.1036 - val_crossentropy: 5.1119
# Epoch 8/100
# 64/64 [==============================] - 34s 535ms/step - loss: 4.0537 - accuracy: 0.1907 - crossentropy: 4.0537 - val_loss: 4.7789 - val_accuracy: 0.1402 - val_crossentropy: 4.7789
# Epoch 9/100
# 64/64 [==============================] - 36s 562ms/step - loss: 4.0841 - accuracy: 0.1903 - crossentropy: 4.0841 - val_loss: 4.7338 - val_accuracy: 0.1293 - val_crossentropy: 4.7338
# Epoch 10/100
# 64/64 [==============================] - 34s 528ms/step - loss: 3.9679 - accuracy: 0.2056 - crossentropy: 3.9679 - val_loss: 4.4632 - val_accuracy: 0.1665 - val_crossentropy: 4.4632
# Epoch 11/100
# 64/64 [==============================] - 34s 539ms/step - loss: 3.7965 - accuracy: 0.2273 - crossentropy: 3.7965 - val_loss: 4.0582 - val_accuracy: 0.2007 - val_crossentropy: 4.0582
# Epoch 12/100
# 64/64 [==============================] - 35s 544ms/step - loss: 3.8556 - accuracy: 0.2146 - crossentropy: 3.8556 - val_loss: 4.1329 - val_accuracy: 0.1881 - val_crossentropy: 4.1329
# Epoch 13/100
# 64/64 [==============================] - 34s 536ms/step - loss: 3.8142 - accuracy: 0.2222 - crossentropy: 3.8142 - val_loss: 3.9075 - val_accuracy: 0.2260 - val_crossentropy: 3.9075
# Epoch 14/100
# 64/64 [==============================] - 36s 558ms/step - loss: 3.7082 - accuracy: 0.2362 - crossentropy: 3.7082 - val_loss: 3.7036 - val_accuracy: 0.2489 - val_crossentropy: 3.7036
# Epoch 15/100
# 64/64 [==============================] - 34s 533ms/step - loss: 3.6613 - accuracy: 0.2399 - crossentropy: 3.6613 - val_loss: 3.7418 - val_accuracy: 0.2456 - val_crossentropy: 3.7418
# Epoch 16/100
# 64/64 [==============================] - 35s 544ms/step - loss: 3.6386 - accuracy: 0.2454 - crossentropy: 3.6386 - val_loss: 3.7096 - val_accuracy: 0.2488 - val_crossentropy: 3.7096
# Epoch 17/100
# 64/64 [==============================] - 35s 549ms/step - loss: 3.6440 - accuracy: 0.2484 - crossentropy: 3.6440 - val_loss: 4.6862 - val_accuracy: 0.1273 - val_crossentropy: 4.6862
# Epoch 18/100
# 64/64 [==============================] - 35s 541ms/step - loss: 3.4981 - accuracy: 0.2657 - crossentropy: 3.4981 - val_loss: 3.7300 - val_accuracy: 0.2436 - val_crossentropy: 3.7300
# Epoch 19/100
# 64/64 [==============================] - 35s 542ms/step - loss: 3.5177 - accuracy: 0.2588 - crossentropy: 3.5177 - val_loss: 4.0941 - val_accuracy: 0.1889 - val_crossentropy: 4.0941
# Epoch 20/100
# 64/64 [==============================] - 35s 545ms/step - loss: 3.5622 - accuracy: 0.2551 - crossentropy: 3.5622 - val_loss: 3.6931 - val_accuracy: 0.2550 - val_crossentropy: 3.6931
# Epoch 21/100
# 64/64 [==============================] - 34s 539ms/step - loss: 3.3713 - accuracy: 0.2847 - crossentropy: 3.3713 - val_loss: 3.8281 - val_accuracy: 0.2326 - val_crossentropy: 3.8281
# Epoch 22/100
# 64/64 [==============================] - 35s 546ms/step - loss: 3.4076 - accuracy: 0.2749 - crossentropy: 3.4076 - val_loss: 4.2654 - val_accuracy: 0.2077 - val_crossentropy: 4.2654
# Epoch 23/100
# 64/64 [==============================] - 34s 538ms/step - loss: 3.4237 - accuracy: 0.2819 - crossentropy: 3.4237 - val_loss: 3.5618 - val_accuracy: 0.2754 - val_crossentropy: 3.5618
# Epoch 24/100
# 64/64 [==============================] - 35s 546ms/step - loss: 3.3692 - accuracy: 0.2829 - crossentropy: 3.3692 - val_loss: 3.5047 - val_accuracy: 0.2777 - val_crossentropy: 3.5047
# Epoch 25/100
# 64/64 [==============================] - 35s 545ms/step - loss: 3.2655 - accuracy: 0.3002 - crossentropy: 3.2655 - val_loss: 3.5817 - val_accuracy: 0.2711 - val_crossentropy: 3.5817
# Epoch 26/100
# 64/64 [==============================] - 35s 540ms/step - loss: 3.3364 - accuracy: 0.2891 - crossentropy: 3.3364 - val_loss: 3.8110 - val_accuracy: 0.2354 - val_crossentropy: 3.8110
# Epoch 27/100
# 64/64 [==============================] - 35s 542ms/step - loss: 3.3142 - accuracy: 0.2940 - crossentropy: 3.3142 - val_loss: 3.4174 - val_accuracy: 0.2995 - val_crossentropy: 3.4174
# Epoch 28/100
# 64/64 [==============================] - 34s 532ms/step - loss: 3.1844 - accuracy: 0.3097 - crossentropy: 3.1844 - val_loss: 3.6663 - val_accuracy: 0.2554 - val_crossentropy: 3.6663
# Epoch 29/100
# 64/64 [==============================] - 35s 552ms/step - loss: 3.1943 - accuracy: 0.3151 - crossentropy: 3.1943 - val_loss: 3.3304 - val_accuracy: 0.2974 - val_crossentropy: 3.3304
# Epoch 30/100
# 64/64 [==============================] - 35s 546ms/step - loss: 3.2148 - accuracy: 0.3101 - crossentropy: 3.2148 - val_loss: 3.6059 - val_accuracy: 0.2546 - val_crossentropy: 3.6059
# Epoch 31/100
# 64/64 [==============================] - 34s 536ms/step - loss: 3.1055 - accuracy: 0.3296 - crossentropy: 3.1055 - val_loss: 3.3865 - val_accuracy: 0.3019 - val_crossentropy: 3.3865
# Epoch 32/100
# 64/64 [==============================] - 34s 537ms/step - loss: 3.1183 - accuracy: 0.3230 - crossentropy: 3.1183 - val_loss: 4.3379 - val_accuracy: 0.1703 - val_crossentropy: 4.3379
# Epoch 33/100
# 64/64 [==============================] - 36s 559ms/step - loss: 3.1253 - accuracy: 0.3256 - crossentropy: 3.1253 - val_loss: 3.4836 - val_accuracy: 0.2914 - val_crossentropy: 3.4836
# Epoch 34/100
# 64/64 [==============================] - 34s 536ms/step - loss: 3.1116 - accuracy: 0.3223 - crossentropy: 3.1116 - val_loss: 3.3323 - val_accuracy: 0.3186 - val_crossentropy: 3.3323
# Epoch 35/100
# 64/64 [==============================] - 35s 549ms/step - loss: 3.0726 - accuracy: 0.3334 - crossentropy: 3.0726 - val_loss: 3.6901 - val_accuracy: 0.2530 - val_crossentropy: 3.6901
# Epoch 36/100
# 64/64 [==============================] - 35s 543ms/step - loss: 3.0757 - accuracy: 0.3314 - crossentropy: 3.0757 - val_loss: 3.9256 - val_accuracy: 0.2281 - val_crossentropy: 3.9256
# Epoch 37/100
# 64/64 [==============================] - 35s 542ms/step - loss: 3.0817 - accuracy: 0.3177 - crossentropy: 3.0817 - val_loss: 3.2879 - val_accuracy: 0.3370 - val_crossentropy: 3.2879
# Epoch 38/100
# 64/64 [==============================] - 35s 545ms/step - loss: 2.9444 - accuracy: 0.3448 - crossentropy: 2.9444 - val_loss: 3.3747 - val_accuracy: 0.3125 - val_crossentropy: 3.3747
# Epoch 39/100
# 64/64 [==============================] - 35s 545ms/step - loss: 2.9769 - accuracy: 0.3395 - crossentropy: 2.9769 - val_loss: 3.3532 - val_accuracy: 0.3154 - val_crossentropy: 3.3532
# Epoch 40/100
# 64/64 [==============================] - 34s 531ms/step - loss: 3.0060 - accuracy: 0.3416 - crossentropy: 3.0060 - val_loss: 3.5483 - val_accuracy: 0.2855 - val_crossentropy: 3.5483
# Epoch 41/100
# 64/64 [==============================] - 35s 549ms/step - loss: 2.9535 - accuracy: 0.3501 - crossentropy: 2.9535 - val_loss: 3.2654 - val_accuracy: 0.3387 - val_crossentropy: 3.2654
# Epoch 42/100
# 64/64 [==============================] - 34s 539ms/step - loss: 2.8822 - accuracy: 0.3544 - crossentropy: 2.8822 - val_loss: 3.4284 - val_accuracy: 0.3031 - val_crossentropy: 3.4284
# Epoch 43/100
# 64/64 [==============================] - 34s 533ms/step - loss: 2.9323 - accuracy: 0.3494 - crossentropy: 2.9323 - val_loss: 4.3947 - val_accuracy: 0.1799 - val_crossentropy: 4.3947
# Epoch 44/100
# 64/64 [==============================] - 34s 532ms/step - loss: 2.9579 - accuracy: 0.3478 - crossentropy: 2.9579 - val_loss: 4.1285 - val_accuracy: 0.2142 - val_crossentropy: 4.1285
# Epoch 45/100
# 64/64 [==============================] - 35s 546ms/step - loss: 2.8444 - accuracy: 0.3591 - crossentropy: 2.8444 - val_loss: 3.7927 - val_accuracy: 0.2574 - val_crossentropy: 3.7927
# Epoch 46/100
# 64/64 [==============================] - 35s 545ms/step - loss: 2.8405 - accuracy: 0.3636 - crossentropy: 2.8405 - val_loss: 3.2784 - val_accuracy: 0.3337 - val_crossentropy: 3.2784
# Epoch 47/100
# 64/64 [==============================] - 34s 532ms/step - loss: 2.8575 - accuracy: 0.3616 - crossentropy: 2.8575 - val_loss: 3.4908 - val_accuracy: 0.3080 - val_crossentropy: 3.4908
# Epoch 48/100
# 64/64 [==============================] - 34s 538ms/step - loss: 2.7809 - accuracy: 0.3747 - crossentropy: 2.7809 - val_loss: 3.6042 - val_accuracy: 0.2820 - val_crossentropy: 3.6042
# Epoch 49/100
# 64/64 [==============================] - 35s 543ms/step - loss: 2.7541 - accuracy: 0.3772 - crossentropy: 2.7541 - val_loss: 3.5534 - val_accuracy: 0.2875 - val_crossentropy: 3.5534
# Epoch 50/100
# 64/64 [==============================] - 35s 548ms/step - loss: 2.8333 - accuracy: 0.3676 - crossentropy: 2.8333 - val_loss: 4.1626 - val_accuracy: 0.2166 - val_crossentropy: 4.1626
# Epoch 51/100
# 64/64 [==============================] - 35s 541ms/step - loss: 2.7730 - accuracy: 0.3715 - crossentropy: 2.7730 - val_loss: 3.6029 - val_accuracy: 0.2815 - val_crossentropy: 3.6029
# Epoch 52/100
# 64/64 [==============================] - 34s 534ms/step - loss: 2.7639 - accuracy: 0.3783 - crossentropy: 2.7639 - val_loss: 3.5646 - val_accuracy: 0.2901 - val_crossentropy: 3.5646
# Epoch 53/100
# 64/64 [==============================] - 34s 538ms/step - loss: 2.7269 - accuracy: 0.3840 - crossentropy: 2.7269 - val_loss: 3.5777 - val_accuracy: 0.2815 - val_crossentropy: 3.5777
# Epoch 54/100
# 64/64 [==============================] - 34s 538ms/step - loss: 2.7851 - accuracy: 0.3738 - crossentropy: 2.7851 - val_loss: 3.4820 - val_accuracy: 0.2909 - val_crossentropy: 3.4820
# Epoch 55/100
# 64/64 [==============================] - 35s 548ms/step - loss: 2.6302 - accuracy: 0.4025 - crossentropy: 2.6302 - val_loss: 3.4819 - val_accuracy: 0.3052 - val_crossentropy: 3.4819
# Epoch 56/100
# 64/64 [==============================] - 34s 535ms/step - loss: 2.6807 - accuracy: 0.3885 - crossentropy: 2.6807 - val_loss: 3.8329 - val_accuracy: 0.2598 - val_crossentropy: 3.8329
# Epoch 57/100
# 64/64 [==============================] - 35s 544ms/step - loss: 2.7405 - accuracy: 0.3828 - crossentropy: 2.7405 - val_loss: 4.0978 - val_accuracy: 0.2375 - val_crossentropy: 4.0978
# Epoch 58/100
# 64/64 [==============================] - 35s 543ms/step - loss: 2.6054 - accuracy: 0.4126 - crossentropy: 2.6054 - val_loss: 3.7289 - val_accuracy: 0.2693 - val_crossentropy: 3.7289
# Epoch 59/100
# 64/64 [==============================] - 33s 523ms/step - loss: 2.5813 - accuracy: 0.4099 - crossentropy: 2.5813 - val_loss: 3.2075 - val_accuracy: 0.3497 - val_crossentropy: 3.2075
# Epoch 60/100
# 64/64 [==============================] - 35s 545ms/step - loss: 2.7197 - accuracy: 0.3802 - crossentropy: 2.7197 - val_loss: 3.6053 - val_accuracy: 0.2921 - val_crossentropy: 3.6053
# Epoch 61/100
# 64/64 [==============================] - 35s 541ms/step - loss: 2.6809 - accuracy: 0.3901 - crossentropy: 2.6809 - val_loss: 3.3559 - val_accuracy: 0.3297 - val_crossentropy: 3.3559
# Epoch 62/100
# 64/64 [==============================] - 34s 533ms/step - loss: 2.5718 - accuracy: 0.4077 - crossentropy: 2.5718 - val_loss: 3.6619 - val_accuracy: 0.2860 - val_crossentropy: 3.6619
# Epoch 63/100
# 64/64 [==============================] - 35s 540ms/step - loss: 2.6129 - accuracy: 0.4006 - crossentropy: 2.6129 - val_loss: 3.2595 - val_accuracy: 0.3464 - val_crossentropy: 3.2595
# Epoch 64/100
# 64/64 [==============================] - 35s 543ms/step - loss: 2.6501 - accuracy: 0.3900 - crossentropy: 2.6501 - val_loss: 3.4527 - val_accuracy: 0.3258 - val_crossentropy: 3.4527
# Epoch 65/100
# 64/64 [==============================] - 35s 541ms/step - loss: 2.5234 - accuracy: 0.4151 - crossentropy: 2.5234 - val_loss: 4.0649 - val_accuracy: 0.2254 - val_crossentropy: 4.0649
# Epoch 66/100
# 64/64 [==============================] - 35s 541ms/step - loss: 2.5431 - accuracy: 0.4154 - crossentropy: 2.5431 - val_loss: 3.5582 - val_accuracy: 0.2929 - val_crossentropy: 3.5582
# Epoch 67/100
# 64/64 [==============================] - 34s 536ms/step - loss: 2.5821 - accuracy: 0.4025 - crossentropy: 2.5821 - val_loss: 3.8343 - val_accuracy: 0.2807 - val_crossentropy: 3.8343
# Epoch 68/100
# 64/64 [==============================] - 34s 539ms/step - loss: 2.5655 - accuracy: 0.4090 - crossentropy: 2.5655 - val_loss: 3.4504 - val_accuracy: 0.3297 - val_crossentropy: 3.4504
# Epoch 69/100
# 64/64 [==============================] - 34s 537ms/step - loss: 2.5389 - accuracy: 0.4183 - crossentropy: 2.5389 - val_loss: 3.2203 - val_accuracy: 0.3717 - val_crossentropy: 3.2203
# Epoch 70/100
# 64/64 [==============================] - 35s 540ms/step - loss: 2.5352 - accuracy: 0.4120 - crossentropy: 2.5352 - val_loss: 3.5692 - val_accuracy: 0.3121 - val_crossentropy: 3.5692
# Epoch 71/100
# 64/64 [==============================] - 34s 528ms/step - loss: 2.5116 - accuracy: 0.4212 - crossentropy: 2.5116 - val_loss: 3.3788 - val_accuracy: 0.3435 - val_crossentropy: 3.3788
# Epoch 72/100
# 64/64 [==============================] - 35s 541ms/step - loss: 2.4186 - accuracy: 0.4343 - crossentropy: 2.4186 - val_loss: 3.2471 - val_accuracy: 0.3625 - val_crossentropy: 3.2471
# Epoch 73/100
# 64/64 [==============================] - 35s 540ms/step - loss: 2.5064 - accuracy: 0.4161 - crossentropy: 2.5064 - val_loss: 3.4915 - val_accuracy: 0.3281 - val_crossentropy: 3.4915
# Epoch 74/100
# 64/64 [==============================] - 35s 549ms/step - loss: 2.5460 - accuracy: 0.4117 - crossentropy: 2.5460 - val_loss: 3.2831 - val_accuracy: 0.3545 - val_crossentropy: 3.2831
# Epoch 75/100
# 64/64 [==============================] - 35s 548ms/step - loss: 2.4231 - accuracy: 0.4377 - crossentropy: 2.4231 - val_loss: 3.3997 - val_accuracy: 0.3472 - val_crossentropy: 3.3997
# Epoch 76/100
# 64/64 [==============================] - 34s 538ms/step - loss: 2.4338 - accuracy: 0.4252 - crossentropy: 2.4338 - val_loss: 3.5266 - val_accuracy: 0.3174 - val_crossentropy: 3.5266
# Epoch 77/100
# 64/64 [==============================] - 35s 543ms/step - loss: 2.4547 - accuracy: 0.4194 - crossentropy: 2.4547 - val_loss: 3.6245 - val_accuracy: 0.2999 - val_crossentropy: 3.6245
# Epoch 78/100
# 64/64 [==============================] - 35s 545ms/step - loss: 2.4303 - accuracy: 0.4277 - crossentropy: 2.4303 - val_loss: 3.6748 - val_accuracy: 0.3052 - val_crossentropy: 3.6748
# Epoch 79/100
# 64/64 [==============================] - 35s 554ms/step - loss: 2.3327 - accuracy: 0.4502 - crossentropy: 2.3327 - val_loss: 3.3925 - val_accuracy: 0.3354 - val_crossentropy: 3.3925
# Epoch 80/100
# 64/64 [==============================] - 34s 539ms/step - loss: 2.4434 - accuracy: 0.4274 - crossentropy: 2.4434 - val_loss: 3.7230 - val_accuracy: 0.2953 - val_crossentropy: 3.7230
# Epoch 81/100
# 64/64 [==============================] - 36s 557ms/step - loss: 2.4639 - accuracy: 0.4264 - crossentropy: 2.4639 - val_loss: 3.4379 - val_accuracy: 0.3313 - val_crossentropy: 3.4379
# Epoch 82/100
# 64/64 [==============================] - 34s 535ms/step - loss: 2.2846 - accuracy: 0.4579 - crossentropy: 2.2846 - val_loss: 3.5134 - val_accuracy: 0.3297 - val_crossentropy: 3.5134
# Epoch 83/100
# 64/64 [==============================] - 35s 549ms/step - loss: 2.3809 - accuracy: 0.4430 - crossentropy: 2.3809 - val_loss: 3.6087 - val_accuracy: 0.2999 - val_crossentropy: 3.6087
# Epoch 84/100
# 64/64 [==============================] - 34s 539ms/step - loss: 2.4421 - accuracy: 0.4344 - crossentropy: 2.4421 - val_loss: 3.8054 - val_accuracy: 0.3019 - val_crossentropy: 3.8054
# Epoch 85/100
# 64/64 [==============================] - 35s 544ms/step - loss: 2.3529 - accuracy: 0.4421 - crossentropy: 2.3529 - val_loss: 3.4401 - val_accuracy: 0.3354 - val_crossentropy: 3.4401
# Epoch 86/100
# 64/64 [==============================] - 35s 546ms/step - loss: 2.3318 - accuracy: 0.4436 - crossentropy: 2.3318 - val_loss: 4.3912 - val_accuracy: 0.2256 - val_crossentropy: 4.3912
# Epoch 87/100
# 64/64 [==============================] - 34s 539ms/step - loss: 2.3489 - accuracy: 0.4501 - crossentropy: 2.3489 - val_loss: 3.4013 - val_accuracy: 0.3431 - val_crossentropy: 3.4013
# Epoch 88/100
# 64/64 [==============================] - 35s 542ms/step - loss: 2.3741 - accuracy: 0.4439 - crossentropy: 2.3741 - val_loss: 4.5347 - val_accuracy: 0.2047 - val_crossentropy: 4.5347
# Epoch 89/100
# 64/64 [==============================] - 35s 542ms/step - loss: 2.2509 - accuracy: 0.4619 - crossentropy: 2.2509 - val_loss: 3.3664 - val_accuracy: 0.3562 - val_crossentropy: 3.3664
# Epoch 90/100
# 64/64 [==============================] - 34s 534ms/step - loss: 2.2681 - accuracy: 0.4580 - crossentropy: 2.2681 - val_loss: 3.6172 - val_accuracy: 0.3215 - val_crossentropy: 3.6172
# Epoch 91/100
# 64/64 [==============================] - 35s 546ms/step - loss: 2.3814 - accuracy: 0.4381 - crossentropy: 2.3814 - val_loss: 3.3925 - val_accuracy: 0.3594 - val_crossentropy: 3.3925
# Epoch 92/100
# 64/64 [==============================] - 35s 545ms/step - loss: 2.2539 - accuracy: 0.4648 - crossentropy: 2.2539 - val_loss: 4.8884 - val_accuracy: 0.1950 - val_crossentropy: 4.8884
# Epoch 93/100
# 64/64 [==============================] - 35s 543ms/step - loss: 2.2840 - accuracy: 0.4608 - crossentropy: 2.2840 - val_loss: 3.4654 - val_accuracy: 0.3407 - val_crossentropy: 3.4654
# Epoch 94/100
# 64/64 [==============================] - 35s 546ms/step - loss: 2.3103 - accuracy: 0.4491 - crossentropy: 2.3103 - val_loss: 3.8213 - val_accuracy: 0.2991 - val_crossentropy: 3.8213
# Epoch 95/100
# 64/64 [==============================] - 34s 529ms/step - loss: 2.2162 - accuracy: 0.4759 - crossentropy: 2.2162 - val_loss: 3.1457 - val_accuracy: 0.3823 - val_crossentropy: 3.1457
# Epoch 96/100
# 64/64 [==============================] - 35s 549ms/step - loss: 2.2107 - accuracy: 0.4719 - crossentropy: 2.2107 - val_loss: 3.4293 - val_accuracy: 0.3367 - val_crossentropy: 3.4293
# Epoch 97/100
# 64/64 [==============================] - 35s 541ms/step - loss: 2.2752 - accuracy: 0.4603 - crossentropy: 2.2752 - val_loss: 4.3161 - val_accuracy: 0.2434 - val_crossentropy: 4.3161
# Epoch 98/100
# 64/64 [==============================] - 35s 547ms/step - loss: 2.2812 - accuracy: 0.4604 - crossentropy: 2.2812 - val_loss: 4.0622 - val_accuracy: 0.2583 - val_crossentropy: 4.0622
# Epoch 99/100
# 64/64 [==============================] - 35s 549ms/step - loss: 2.1662 - accuracy: 0.4802 - crossentropy: 2.1662 - val_loss: 4.2664 - val_accuracy: 0.2481 - val_crossentropy: 4.2664
# Epoch 100/100
# 64/64 [==============================] - 34s 526ms/step - loss: 2.2291 - accuracy: 0.4706 - crossentropy: 2.2291 - val_loss: 3.6048 - val_accuracy: 0.3195 - val_crossentropy: 3.6048
